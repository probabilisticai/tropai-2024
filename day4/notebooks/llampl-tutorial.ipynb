# %% [markdown]
# # Sequential Monte-Carlo (SMC) Steering of Large Language Models

# %% [markdown]
# A fundamental problem with Large Language Models (LLM) is *controlled generation*&mdash;The problem of generating text that follows certain  constraints. LLaMPPL is a probabilistic programming language designed to  solve this problem by using LLMs as primitive probability distributions which can be conditioned and constrained using methods from *sequential Monte-Carlo*.
#
# Note that the easiest-to-use version of LLaMPPL is current HFPPL (Hugging Face Probabilistic Programming Language) which makes use of  HuggingFace to work with transformer-based LLMs.
#
# The code base, documentation, and link to the paper can be found [here](https://github.com/probcomp/hfppl?tab=readme-ov-file).
#
# In the examples below, we make use of Llama2. You will need to provide your own HuggingFace authorization token if you want to use this model.

# %%
from hfppl import Model, CachedCausalLM, Token, LMContext, smc_standard, smc_steer, TokenCategorical, Bernoulli
from string import punctuation

LLM = CachedCausalLM.from_pretrained("meta-llama/Llama-2-7b-hf", auth_token="YOUR TOKEN HERE")
LLM.batch_size = 40
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/models/auto/tokenization_auto.py:711: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:472: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# # Generating Sentences with Short Words
#
# To implement a LLaMPPL model, we define a subclass of type `Model` and implement the `__init__` and `step` functions (minimally).
#
# Within the body of the model we then make use of the following.
#
#  - `sample(distribution, proposal)`: Sample a value `value` and the multiply the importance weight by `distribution(value)/proposal(value)`. Note that `sample(distribution)` will use `distribution` as the proposal (i.e., sample from the joint) and thus the importance weight will be `1`.
#  - `observe(dist, value)`: Force the distribution to take on `value` and multiply the (marginal) likelihood of `value` into the importance weight.
#  - `intervene(dist, value)`:
#  - `condition(boolean)`: Multiply the importance weight by 1/0 depending on whether boolean is true.
#  - `score(value)`: Multiply the importance weight by `exp(value)`.
#
# The fundamental distribution in LLaMPPL is the `LMContext` distribution which represents a stateful distribution over next tokens give a prompt and previously generated tokens.
#
# $$P_{\mathrm{LLM}}(x_i | \mathrm{prompt}, \mathbf{x}_{<i})$$
#
# In particular, `LMContext.next_token()` returns this distribution.
#
# Calling the `sample` member method `LMContext` will statefully update the context (i.e., the string of tokens generated so far).
#
# In all of the examples below, we will make extensive use of *masks*, that is, lists of allowed tokens under the LLM distribution.
#
# Our first example is to generate text which only consists of words of five characters or less. First we will construct a mask for this problem.

# %%
MASKS = {i : set(j for (j,v) in enumerate(LLM.vocab)
                 if j != LLM.tokenizer.eos_token_id and '\n' not in v 
                 and
                 any(c.isalpha() or c in punctuation for c in v) and
                 len(v.strip()) <= 5 and (not v[0].isalpha() 
                                          or i+len(v) <= 5))
             for i in range(6)}

# %% [markdown]
# Now we are in a position to implement a subclass of `Model`. Note that our code makes heavy use of Python's asychronous computing capabilities; in particular, it uses `await` and `async`. This is to do automatic batching.

# %%
class ShortWordModel(Model):
    def __init__(self, prompt, max_tokens):
        super().__init__()
        self.lm         = LMContext(LLM, prompt)
        self.q          = LMContext(LLM, prompt)
        self.prompt_len = len(str(self.lm.s))
        self.max_tokens = max_tokens


    async def step(self):
        # Which tokens are allowed?
        mask = self.active_constraint_mask()

        # Generate proposed token.
        token = await self.sample(self.lm.next_token(),
                                  proposal = await self.proposal(mask))

        # Reduce number of max tokens remaining
        self.max_tokens -= 1

        print(str(self.lm.s)[self.prompt_len:])

        # Check if done
        if token == LLM.tokenizer.eos_token_id or self.max_tokens == 0:
            self.finish()

    def active_constraint_mask(self):
        string_so_far = str(self.lm.s)
        words = string_so_far.split()
        last_word = words[-1] if len(words) > 0 else ""
        return MASKS[min(5, len(last_word))]

    async def proposal(self, mask):
        string_so_far = str(self.lm.s)

        # Force the proposal StatefulLM to adhere to this mask
        await self.intervene(self.q.mask_dist(mask), True)

        # Return the proposal's modified next-token distribution
        return self.q.next_token()

# %% [markdown]
# We perform inference in a LLaMPPL model using either the `smc_standard` function (which implements sequential Monte-Carlo with resampling) or `smc_steer` which implements a version of SMC which attempts to increase particle diversity by sampling without replacement.

# %%
# From Politico.com
prompt = """<|endoftext|>3 things to watch …

1. The return of the House means new energy for the GOP’s Biden impeachment push, and Democrats are starting their pushback early. Rep. Jamie Raskin (D-Md.) is out this morning with a 14-page rebuttal memo that seeks to paint the GOP campaign as a “complete and total bust” and an attempt at distracting from the “overwhelming evidence of [Trump’s] criminal and corrupt conduct during his term of office.”

2. The Senate is back this evening for a bed-check vote. With Minority Leader Mitch McConnell having successfully quieted (public) chatter about his health, expect senators to be quizzed anew about Sen. Tommy Tuberville’s (R-Ala.) Pentagon nominee blockade, especially with the Joint Chiefs chair, Gen. Mark Milley, just weeks away from retirement and the confirmation of his successor, Gen. C.Q. Brown, in limbo.

3."""

LLM.cache_kv(LLM.tokenizer.encode(prompt))

async def main():
    constraint_model = ShortWordModel(prompt, 50)
    particles = await smc_standard(constraint_model, 20)
    for p in particles:
        print(str(p.lm.s)[p.prompt_len:])

# %%
# Run the model
await main()
# Out:
#  Vice
#  Mc
#  The
#  D
#  Four
#  We
#  When
#  G
#  And
#  Ex
#  The
#  Sand
#  With
#  The
#  Head
#  For
#  P
#  Read
#  F
#  Per
#  Vice Pres
#  McCon
#  The White
#  Dems
#  Four years
#  We spent
#  When it
#  Gov
#  And the
#  Exc
#  The new
#  Sandy
#  With his
#  The UN
#  Head to
#  For the
#  Penc
#  Read the
#  Fake
#  Per a
#  Vice Pres.
#  McCon is
#  The White House
#  Dems did
#  Four years from
#  We spent this
#  When it comes
#  Gov.
#  And the first
#  Excru
#  The new COVID
#  Sandy O
#  With his water
#  The UN chief
#  Head to No
#  For the first
#  Pencˇ
#  Read the full
#  Fake news
#  Per a twe
#  Vice Pres. Kam
#  McCon is set
#  The White House is
#  Dems did pass
#  Four years from now
#  We spent this week
#  When it comes to
#  Gov. Ron
#  And the first fil
#  Excru t
#  The new COVID-
#  Sandy Ocho
#  With his water rec
#  The UN chief is
#  Head to Noon
#  For the first time
#  Pencˇ a
#  Read the full ag
#  Fake news is
#  Per a tweet
#  Vice Pres. Kamia
#  McCon is set to
#  The White House is eye
#  Dems did pass a
#  Four years from now,
#  We spent this week doing
#  When it comes to fil
#  Gov. Ron De
#  And the first filib
#  Excru tion
#  The new COVID- led
#  Sandy Ochoa
#  With his water recy
#  The UN chief is visit
#  Head to Noon,
#  For the first time since
#  Pencˇ a {
#  Read the full agend
#  Fake news is the
#  Per a tweet,
#  When it comes to filib
#  Dems did pass a COVID
#  When it comes to filib
#  Per a tweet, there
#  Gov. Ron DeS
#  Gov. Ron DeS
#  For the first time since Ted
#  Four years from now, just
#  The White House is eye-
#  Per a tweet, the
#  Fake news is the focus
#  The UN chief is visit in
#  Dems did pass a new
#  The White House is eye-
#  Gov. Ron DeS
#  The White House is eye-
#  For the first time since Sen
#  When it comes to filib
#  The White House is eye-
#  For the first time since the
#  When it comes to filib dzie
#  Dems did pass a COVID-
#  When it comes to filib maja
#  Per a tweet, there was
#  Gov. Ron DeSb
#  Gov. Ron DeSav
#  For the first time since Ted Cruz
#  Four years from now, just when
#  The White House is eye-p
#  Per a tweet, the White
#  Fake news is the focus of
#  The UN chief is visit in Sri
#  Dems did pass a new spot
#  The White House is eye-c
#  Gov. Ron DeSha
#  The White House is eye-w
#  For the first time since Sen.
#  When it comes to filib först
#  The White House is eye-b
#  For the first time since the Un
#  For the first time since the Unite
#  Dems did pass a new spot,
#  Per a tweet, there was a
#  For the first time since Ted Cruz sw
#  Fake news is the focus of ton
#  For the first time since Ted Cruz crack
#  For the first time since Ted Cruz to
#  Per a tweet, there was a
#  Dems did pass a COVID- aid
#  Dems did pass a COVID-'
#  Fake news is the focus of the
#  Fake news is the focus of big
#  For the first time since the Unab
#  Per a tweet, there was an
#  For the first time since Sen. Ch
#  Per a tweet, the White House
#  Fake news is the focus of a
#  Per a tweet, the White House
#  For the first time since Sen. Brad
#  Per a tweet, there was an
#  For the first time since the Unite the
#  Dems did pass a new spot, V
#  Per a tweet, there was a large
#  For the first time since Ted Cruz swore
#  Fake news is the focus of toned
#  For the first time since Ted Cruz crack that
#  For the first time since Ted Cruz topp
#  Per a tweet, there was a sharp
#  Dems did pass a COVID- aid for
#  Dems did pass a COVID-' emer
#  Fake news is the focus of the sixth
#  Fake news is the focus of big-
#  For the first time since the Unabo
#  Per a tweet, there was an anti
#  For the first time since Sen. Chuck
#  Per a tweet, the White House Cor
#  Fake news is the focus of a new
#  Per a tweet, the White House and
#  For the first time since Sen. Brad Sh
#  Per a tweet, there was an intr
#  For the first time since the Unite the Right
#  Dems did pass a new spot, Vot
#  Per a tweet, there was a large infl
#  For the first time since Ted Cruz swore in
#  Fake news is the focus of toned-
#  For the first time since Ted Cruz crack that D
#  For the first time since Ted Cruz toppl
#  Per a tweet, there was a sharp drop
#  Dems did pass a COVID- aid for v
#  Dems did pass a COVID-' emerg
#  Fake news is the focus of the sixth day
#  Fake news is the focus of big-g
#  For the first time since the Unabo Bank
#  Per a tweet, there was an anti-
#  For the first time since Sen. Chuck Gr
#  Per a tweet, the White House Coron
#  Fake news is the focus of a new poll
#  Per a tweet, the White House and Peter
#  For the first time since Sen. Brad Shim
#  Per a tweet, there was an intru
#  For the first time since Sen. Chuck Grass
#  Fake news is the focus of a new poll of
#  Fake news is the focus of a new poll from
#  Per a tweet, the White House and Peter Navar
#  For the first time since Sen. Chuck Grass
#  For the first time since Sen. Chuck Grass
#  For the first time since the Unite the Right r
#  For the first time since the Unite the Right r
#  Per a tweet, there was an anti-*
#  Per a tweet, there was an anti-<-
#  For the first time since the Unite the Right r
#  Fake news is the focus of the sixth day with
#  Per a tweet, the White House Coron-
#  Per a tweet, there was a large influ
#  Per a tweet, the White House Coron av
#  For the first time since the Unite the Right r
#  Per a tweet, there was a sharp drop in
#  For the first time since Sen. Chuck Grass
#  For the first time since Sen. Chuck Grass
#  Fake news is the focus of a new poll warn
#  For the first time since Sen. Chuck Grass-
#  Fake news is the focus of a new poll of con
#  Fake news is the focus of a new poll from the
#  Per a tweet, the White House and Peter Navar-
#  For the first time since Sen. Chuck Grass pro
#  For the first time since Sen. Chuck Grass-
#  For the first time since the Unite the Right rally
#  For the first time since the Unite the Right ral
#  Per a tweet, there was an anti-* Gold
#  Per a tweet, there was an anti-<- |
#  For the first time since the Unite the Right rally
#  Fake news is the focus of the sixth day with tens
#  Per a tweet, the White House Coron- pan
#  Per a tweet, there was a large influ (
#  Per a tweet, the White House Coron avat
#  For the first time since the Unite the Right rally
#  Per a tweet, there was a sharp drop in broad
#  For the first time since Sen. Chuck Grass (
#  For the first time since Sen. Chuck Grass-
#  Fake news is the focus of a new poll warn of
#  Fake news is the focus of a new poll warn of the
#  Fake news is the focus of the sixth day with tens of
#  Fake news is the focus of the sixth day with tens of
#  Fake news is the focus of a new poll from the AP
#  For the first time since the Unite the Right rally,
#  For the first time since the Unite the Right rally in
#  Per a tweet, there was a sharp drop in broad repo
#  Fake news is the focus of a new poll of condo
#  Fake news is the focus of a new poll of congr
#  Fake news is the focus of a new poll from the Gr
#  For the first time since the Unite the Right rally
#  For the first time since the Unite the Right ralro
#  Per a tweet, there was a sharp drop in broad ret
#  Fake news is the focus of a new poll from the AP
#  Fake news is the focus of the sixth day with tens of
#  For the first time since the Unite the Right rally in
#  Fake news is the focus of a new poll from the P
#  For the first time since the Unite the Right ralD
#  Fake news is the focus of the sixth day with tens of
#  Per a tweet, there was a sharp drop in broad-
#  Fake news is the focus of a new poll warn of the d
#  Fake news is the focus of the sixth day with tens of J
#  Fake news is the focus of the sixth day with tens of state
#  Fake news is the focus of a new poll from the AP,
#  For the first time since the Unite the Right rally, which
#  For the first time since the Unite the Right rally in Char
#  Per a tweet, there was a sharp drop in broad repo,
#  Fake news is the focus of a new poll of condo dwell
#  Fake news is the focus of a new poll of congr YES
#  Fake news is the focus of a new poll from the Grinn
#  For the first time since the Unite the Right rally in
#  For the first time since the Unite the Right ralro vs
#  Per a tweet, there was a sharp drop in broad retri
#  Fake news is the focus of a new poll from the AP-
#  Fake news is the focus of the sixth day with tens of other
#  For the first time since the Unite the Right rally in Char
#  Fake news is the focus of a new poll from the Pew
#  For the first time since the Unite the Right ralD back
#  Fake news is the focus of the sixth day with tens of arr
#  Per a tweet, there was a sharp drop in broad- and
#  For the first time since the Unite the Right rally in Charl
#  For the first time since the Unite the Right rally, which left
#  Fake news is the focus of a new poll from the AP-N
#  Fake news is the focus of a new poll from the Grinn apart
#  Fake news is the focus of a new poll from the Grinn.
#  For the first time since the Unite the Right rally, which drew
#  Fake news is the focus of a new poll from the Grinn Tax
#  For the first time since the Unite the Right rally in Charl
#  For the first time since the Unite the Right rally in Charl
#  Fake news is the focus of a new poll of condo dwell-
#  For the first time since the Unite the Right rally in Charl
#  Fake news is the focus of a new poll from the AP, which
#  Fake news is the focus of a new poll warn of the diz
#  For the first time since the Unite the Right rally in Charl
#  For the first time since the Unite the Right rally in Charl
#  Fake news is the focus of a new poll from the AP-N
#  Fake news is the focus of a new poll from the AP-N
#  Fake news is the focus of a new poll from the AP, which
#  Fake news is the focus of a new poll from the Grinn Post
#  Fake news is the focus of a new poll from the Grinn We
#  For the first time since the Unite the Right rally in Charl-
#  For the first time since the Unite the Right rally, which left an
#  Fake news is the focus of a new poll from the AP-N.
#  Fake news is the focus of a new poll from the Grinn apart from
#  Fake news is the focus of a new poll from the Grinn. News
#  For the first time since the Unite the Right rally, which drew white
#  Fake news is the focus of a new poll from the Grinn Tax Group
#  For the first time since the Unite the Right rally in Charl-
#  For the first time since the Unite the Right rally in Charl-
#  Fake news is the focus of a new poll of condo dwell- ers
#  For the first time since the Unite the Right rally in Charl Tor
#  Fake news is the focus of a new poll from the AP, which shows
#  Fake news is the focus of a new poll warn of the dizzy
#  For the first time since the Unite the Right rally in Charl-
#  For the first time since the Unite the Right rally in Charl-
#  Fake news is the focus of a new poll from the AP-NM
#  Fake news is the focus of a new poll from the AP-N.
#  Fake news is the focus of a new poll from the AP, which finds
#  Fake news is the focus of a new poll from the Grinn Post-
#  Fake news is the focus of a new poll from the Grinn Weird
#  For the first time since the Unite the Right rally, which drew white supre
#  Fake news is the focus of a new poll from the AP, which shows how
#  Fake news is the focus of a new poll from the AP, which shows that
#  For the first time since the Unite the Right rally, which left an anti
#  Fake news is the focus of a new poll from the AP, which shows that
#  Fake news is the focus of a new poll from the AP, which shows that
#  Fake news is the focus of a new poll from the AP, which finds that
#  For the first time since the Unite the Right rally, which left an anti
#  For the first time since the Unite the Right rally, which left an anti
#  Fake news is the focus of a new poll from the AP, which shows that
#  Fake news is the focus of a new poll from the AP, which shows more
#  Fake news is the focus of a new poll from the AP, which finds that
#  Fake news is the focus of a new poll from the AP, which finds that
#  Fake news is the focus of a new poll from the AP, which shows that
#  Fake news is the focus of a new poll from the AP, which finds that
#  For the first time since the Unite the Right rally, which left an N
#  Fake news is the focus of a new poll from the AP, which shows that
#  Fake news is the focus of a new poll from the AP, which shows pl
#  For the first time since the Unite the Right rally, which left an innoc
#  Fake news is the focus of a new poll from the AP, which shows most
#  For the first time since the Unite the Right rally, which drew white supre мм
#  Fake news is the focus of a new poll from the AP, which shows how domin
#  Fake news is the focus of a new poll from the AP, which shows that just
#  For the first time since the Unite the Right rally, which left an anti-
#  Fake news is the focus of a new poll from the AP, which shows that eight
#  Fake news is the focus of a new poll from the AP, which shows that a
#  Fake news is the focus of a new poll from the AP, which finds that less
#  For the first time since the Unite the Right rally, which left an anti-
#  For the first time since the Unite the Right rally, which left an anti-
#  Fake news is the focus of a new poll from the AP, which shows that favor
#  Fake news is the focus of a new poll from the AP, which shows more vot
#  Fake news is the focus of a new poll from the AP, which finds that one
#  Fake news is the focus of a new poll from the AP, which finds that just
#  Fake news is the focus of a new poll from the AP, which shows that nine
#  Fake news is the focus of a new poll from the AP, which finds that more
#  For the first time since the Unite the Right rally, which left an NBC
#  Fake news is the focus of a new poll from the AP, which shows that just
#  Fake news is the focus of a new poll from the AP, which shows plur
#  For the first time since the Unite the Right rally, which left an innoc также
#  Fake news is the focus of a new poll from the AP, which shows most vot
#  For the first time since the Unite the Right rally, which drew white supre ммc
#  Fake news is the focus of a new poll from the AP, which shows how domin-
#  Fake news is the focus of a new poll from the AP, which shows that just one
#  For the first time since the Unite the Right rally, which left an anti- fasc
#  Fake news is the focus of a new poll from the AP, which shows that eight in
#  Fake news is the focus of a new poll from the AP, which shows that a third
#  Fake news is the focus of a new poll from the AP, which finds that less than
#  For the first time since the Unite the Right rally, which left an anti- fasc
#  For the first time since the Unite the Right rally, which left an anti- fasc
#  Fake news is the focus of a new poll from the AP, which shows that favor for
#  Fake news is the focus of a new poll from the AP, which shows more voter
#  Fake news is the focus of a new poll from the AP, which finds that one-
#  Fake news is the focus of a new poll from the AP, which finds that just one
#  Fake news is the focus of a new poll from the AP, which shows that nine in
#  Fake news is the focus of a new poll from the AP, which finds that more than
#  For the first time since the Unite the Right rally, which left an NBC rep
#  Fake news is the focus of a new poll from the AP, which shows that just two
#  Fake news is the focus of a new poll from the AP, which shows plur soci
#  For the first time since the Unite the Right rally, which left an innoc также ж
#  Fake news is the focus of a new poll from the AP, which shows most voter
#  Fake news is the focus of a new poll from the AP, which finds that less than half
#  Fake news is the focus of a new poll from the AP, which shows that eight in ten
#  Fake news is the focus of a new poll from the AP, which finds that one-t
#  Fake news is the focus of a new poll from the AP, which shows that eight in ten
#  Fake news is the focus of a new poll from the AP, which finds that one- in
#  For the first time since the Unite the Right rally, which left an NBC rep still
#  Fake news is the focus of a new poll from the AP, which shows that nine in ten
#  Fake news is the focus of a new poll from the AP, which shows that a third of
#  Fake news is the focus of a new poll from the AP, which shows that nine in every
#  Fake news is the focus of a new poll from the AP, which finds that more than two
#  Fake news is the focus of a new poll from the AP, which finds that more than half
#  Fake news is the focus of a new poll from the AP, which finds that one-e
#  Fake news is the focus of a new poll from the AP, which finds that one-t
#  Fake news is the focus of a new poll from the AP, which finds that more than half
#  Fake news is the focus of a new poll from the AP, which shows that just two in
#  Fake news is the focus of a new poll from the AP, which shows that a third of
#  Fake news is the focus of a new poll from the AP, which shows that eight in ten
#  Fake news is the focus of a new poll from the AP, which shows that just two in
#  Fake news is the focus of a new poll from the AP, which finds that one-t
#  Fake news is the focus of a new poll from the AP, which shows that nine in ten
#  Fake news is the focus of a new poll from the AP, which shows that just two in five
#  Fake news is the focus of a new poll from the AP, which shows that just two in five
#  Fake news is the focus of a new poll from the AP, which shows that a third of vot
#  Fake news is the focus of a new poll from the AP, which finds that more than half of
#  Fake news is the focus of a new poll from the AP, which finds that more than half of
#  Fake news is the focus of a new poll from the AP, which shows that just two in four
#  Fake news is the focus of a new poll from the AP, which finds that more than two-
#  Fake news is the focus of a new poll from the AP, which finds that more than half of
#  Fake news is the focus of a new poll from the AP, which finds that more than half of
#  Fake news is the focus of a new poll from the AP, which shows that just two in five
#  Fake news is the focus of a new poll from the AP, which shows that a third of rep
#  Fake news is the focus of a new poll from the AP, which finds that more than two-
#  Fake news is the focus of a new poll from the AP, which finds that less than half of
#  Fake news is the focus of a new poll from the AP, which shows that just two in five
#  Fake news is the focus of a new poll from the AP, which finds that more than half of
#  Fake news is the focus of a new poll from the AP, which shows that just two in three
#  Fake news is the focus of a new poll from the AP, which finds that less than half of
#  Fake news is the focus of a new poll from the AP, which shows that a third of all
#  Fake news is the focus of a new poll from the AP, which shows that a third of the
#  Fake news is the focus of a new poll from the AP, which shows that a third of all
#  Fake news is the focus of a new poll from the AP, which shows that just two in five vot
#  Fake news is the focus of a new poll from the AP, which shows that just two in five vot
#  Fake news is the focus of a new poll from the AP, which shows that a third of voter
#  Fake news is the focus of a new poll from the AP, which finds that more than half of adult
#  Fake news is the focus of a new poll from the AP, which finds that more than half of vot
#  Fake news is the focus of a new poll from the AP, which shows that just two in four (
#  Fake news is the focus of a new poll from the AP, which finds that more than two-e
#  Fake news is the focus of a new poll from the AP, which finds that more than half of all
#  Fake news is the focus of a new poll from the AP, which finds that more than half of U
#  Fake news is the focus of a new poll from the AP, which shows that just two in five adult
#  Fake news is the focus of a new poll from the AP, which shows that a third of repor
#  Fake news is the focus of a new poll from the AP, which finds that more than two- third
#  Fake news is the focus of a new poll from the AP, which finds that less than half of adult
#  Fake news is the focus of a new poll from the AP, which shows that just two in five vot
#  Fake news is the focus of a new poll from the AP, which finds that more than half of vot
#  Fake news is the focus of a new poll from the AP, which shows that just two in three vot
#  Fake news is the focus of a new poll from the AP, which finds that less than half of those
#  Fake news is the focus of a new poll from the AP, which shows that a third of all vot
#  Fake news is the focus of a new poll from the AP, which shows that a third of the elect
#  Fake news is the focus of a new poll from the AP, which shows that a third of all vot
#  Fake news is the focus of a new poll from the AP, which shows that just two in five voter
#  Fake news is the focus of a new poll from the AP, which shows that just two in five voter
#  Fake news is the focus of a new poll from the AP, which shows that a third of voter doubt
#  Fake news is the focus of a new poll from the AP, which finds that more than half of adult Trump
#  Fake news is the focus of a new poll from the AP, which finds that more than half of voter
#  Fake news is the focus of a new poll from the AP, which shows that just two in four (or
#  Fake news is the focus of a new poll from the AP, which finds that more than two-e-
#  Fake news is the focus of a new poll from the AP, which finds that more than half of all the
#  Fake news is the focus of a new poll from the AP, which finds that more than half of U.
#  Fake news is the focus of a new poll from the AP, which shows that just two in five adult men
#  Fake news is the focus of a new poll from the AP, which shows that a third of repor-
#  Fake news is the focus of a new poll from the AP, which finds that more than two- third of
#  Fake news is the focus of a new poll from the AP, which finds that less than half of adult Filip
#  Fake news is the focus of a new poll from the AP, which shows that just two in five voter
#  Fake news is the focus of a new poll from the AP, which finds that more than half of voter
#  Fake news is the focus of a new poll from the AP, which shows that just two in three voter
#  Fake news is the focus of a new poll from the AP, which finds that less than half of those de
#  Fake news is the focus of a new poll from the AP, which shows that a third of all vot-
#  Fake news is the focus of a new poll from the AP, which shows that a third of the elect came
#  Fake news is the focus of a new poll from the AP, which shows that a third of all voter

# %% [markdown]
# # Generating Haikus

# %% [markdown]
# A haiku is a poem of three lines where the first and last line contain five syllables and the middle line seven. Let's write a LLaMPPL program for generating Haikus.
#
# First, let's write a prompt.

# %%
# Replace last line of this prompt with the title you want for your Haiku.
haiku_prompt = """A haiku is a poem that consists of three lines. The first line has five syllables; the second line has seven syllables; and the third line has five syllables.

Here are some example Haikus. Note how they tend to end on a somewhat surprising or otherwise satisfying note, and are not repetitive at the end.

1. "Portrait"
Sweet smell of wet flowers
Over an evening garden.
Your portrait, perhaps?

2. "River of Love"
love between us is
speech and breath. loving you is
a long river running.

3. "Keys"
I search for my keys
in a million places, but
they are in my hand.

3. "Practice"
I write, erase, rewrite
Erase again, and then
A poppy blooms.

4. "Caterpillar"
A caterpillar,
this deep in fall –
still not a butterfly.

5. "My Left Foot"
"""

LLM.cache_kv(LLM.tokenizer.encode(haiku_prompt))

# %% [markdown]
# Next, let's write a helper function that can count syllables.

# %%
import nltk

# Download the CMU Pronouncing Dictionary (if you haven't already)
nltk.download('cmudict')

from nltk.corpus import cmudict

CMUDICT = cmudict.dict()

def count_syllables(word):
    
    # Use the dictionary to get the list of possible phonetic 
    # representations for the word
    phonetic_transcriptions = CMUDICT.get(word.lower(), [])
    
    # Count the number of syllables based on the number of phonetic 
    # transcriptions
    syllable_count = min([len([ph for ph in transcription 
                               if ph[-1].isdigit()]) 
                          for transcription 
                          in phonetic_transcriptions], default=0)
    
    return syllable_count
# Out:
# [nltk_data] Downloading package cmudict to /home/timo/nltk_data...
# [nltk_data]   Package cmudict is already up-to-date!

# %% [markdown]
# In order to better understand the advantages of LLaMPPL, let's try generating Haikus directly from the LLM. We can do this by writing a LLaMPL program that introduces no constraints.

# %%
class BasicHaiku(Model):
    
    def __init__(self, prompt, max_tokens):
        super().__init__()
        self.context = LMContext(LLM, prompt)
        self.tokens_left = max_tokens
    
    async def step(self):
        token = await self.sample(self.context.next_token())
        self.tokens_left -= 1
        
        if self.tokens_left == 0 or token.token_id == LLM.tokenizer.eos_token_id:
            self.finish()
        
        print(str(self.context))

# %% [markdown]
# Note the code above makes use of `sample` with no proposal distribution. Thus it samples directly from the LLM itself, implementing no conditioning or other constraints.

# %%
#LLM.batch_size = 40
#particles = await smc_steer(BasicHaiku(haiku_prompt), 15, 6)
particles = await smc_standard(BasicHaiku(haiku_prompt, 25), 120)
print("--------")
for (i,particle) in enumerate(particles):
    print(f"Poem {i} (weight {particle.weight}):")
    print(f"{particle.context}\n------------------\n")
# Out:
# The
# The
# I
# I
# I
# I
# The
# I
# I
# I
# I
# I
# Just
# I
# my
# my
# My
# E
# Am
# My
# An
# My
# I
# My
# a
# Long
# My
# My
# T
# My
# At
# When
# ast
# Fe
# I
# My
# My
# My
# Look
# My
# My
# F
# My
# My
# Green
# I
# Wh
# Qu
# It
# My
# My
# T
# My
# A
# My
# My
# This
# My
# Ha
# My
# my
# Left
# My
# My
# You
# I
# I
# Bre
# It
# My
# Do
# My
# left
# this
# This
# My
# I
# My
# J
# I
# F
# as
# L
# My
# And
# my
# I
# my
# In
# My
# My
# 3
# my
# My
# They
# My
# Every
# My
# My
# T
# while
# If
# To
# My
# It
# My
# This
# My
# My
# My
# With
# If
# My
# `
# An
# My
# My
# Al
# My
# A
# The left
# In a
# The left
# I can
# Just one
# I walk
# my left
# my left
# My left
# Ever
# Am I
# My left
# An app
# My left
# I paint
# My left
# a painting
# Long ago
# My left
# My left
# Tick
# My left
# At the
# When I
# astounding
# Feet
# I step
# My left
# My left
# My left
# Look,
# My left
# My left
# Faw
# My left
# My left
# Green grass
# I gli
# While
# Quite
# It is
# My left
# My left
# Tod
# My left
# A left
# My left
# My left
# This is
# My left
# Haib
# My left
# my left
# Left now
# My left
# My left
# You are
# I can
# I press
# Breaking
# It'
# My left
# Doing
# My left
# left and
# this lost
# This hip
# My left
# I’
# My left
# Jump
# I'
# Falling
# asleep
# The Train
# Lack
# My left
# And now
# my left
# I w
# my left
# I rise
# My left
# My left
# 3D
# I step
# my left
# My left
# They look
# My left
# Every morning
# My left
# My left
# Tapping
# while my
# I break
# If I
# To my
# My left
# I am
# It’
# My left
# This is
# My left
# I have
# My left
# My left
# I trust
# I sat
# With left
# If you
# My mind
# `I
# Another
# My left
# My left
# I look
# Always
# My Left
# A left
# The left foot
# In a plane
# The left foot
# I can'
# Just one foot
# I walk with
# my left foot
# my left foot
# My left foot
# Ever under
# Am I really
# My left foot
# An apples
# My left foot
# I paint with
# My left foot
# a painting is
# Long ago,
# My left foot
# My left foot
# Ticklish
# My left foot
# At the instruct
# When I play
# astounding things
# Feet carry
# I step left
# My left foot
# My left foot
# My left foot
# Look, my
# My left foot
# My left foot
# Fawning
# My left foot
# My left foot
# Green grass is
# I glide
# While I
# Quite leg
# It is a
# My left foot
# My left foot
# Today
# My left foot
# A left foot
# My left foot
# My left foot
# This is the
# My left foot
# Haibun
# My left foot
# my left foot
# Left now,
# My left foot
# My left foot
# You are looking
# I can’
# I press my
# Breaking news
# It's
# My left foot
# Doing my
# My left foot
# left and right
# this lost sh
# This hip crack
# My left foot
# I’ll
# My left hand
# Jumping
# I'm
# Falling,
# asleep in
# The Train Ch
# Lack g
# My left foot
# And now my
# my left foot
# I wake
# my left foot
# I rise each
# My left foot
# My left foot
# 3D map
# I step into
# my left foot
# My left foot
# They look into
# My left foot
# Every morning I
# My left foot
# My left foot
# Tapping my
# while my left
# I break the
# If I lose
# To my ad
# My left foot
# I am a
# It’s
# My left foot
# This is the
# My left foot
# I have lost
# My left foot
# My left foot
# I trust my
# I sat l
# With left foot
# If you hurt
# My mind left
# `I have
# Another day
# My left foot
# My left foot
# I look b
# Always,
# My Left foot
# A left foot
# The left foot
#
# In a plane –
# A left foot,
# I can't
# Just one foot div
# I walk with one
# my left foot hurt
# my left foot knows
# My left foot ach
# Ever under wise
# Am I really the
# My left foot sh
# An appleseed
# My left foot is
# I paint with my
# My left foot writes
# a painting is da
# Long ago, when
# My left foot pain
# My left foot flo
# Ticklish my
# My left foot let
# At the instructor
# When I play piano
# astounding things:
# Feet carry me
# I step left
#
# My left foot it
# My left foot k
# My left foot falls
# Look, my left
# My left foot asks
# My left foot
#
# Fawning,
# My left foot is
# My left foot
#
# Green grass is warm
# I glide through
# While I was
# Quite legless
# It is a dear
# My left foot p
# My left foot:
# Today,
# My left foot:
# A left foot is
# My left foot stays
# My left foot
#
# This is the left
# My left foot,
# Haibun,
# My left foot circles
# my left foot,
# Left now, and
# My left foot
#
# My left foot hur
# You are looking at
# I can’t
# I press my left
# Breaking news:
# It's my
# My left foot is
# Doing my push
# My left foot lost
# left and right;
# this lost shoe
# This hip cracked
# My left foot,
# I’ll go
# My left hand is
# Jumping to
# I'm walking
# Falling, again
# asleep in a
# The Train Chug
# Lack gumption
# My left foot’
# And now my left
# my left foot
#
# I wake twice
# my left foot,
# I rise each morning
# My left foot is
# My left foot d
# 3D map,
# I step into ice
# my left foot is
# My left foot doesn
# They look into his
# My left foot is
# Every morning I call
# My left foot is
# My left foot is
# Tapping my foot
# while my left foot
# I break the ice
# If I lose control
# To my adoring
# My left foot,
# I am a star
# It’s really
# My left foot,
# The left foot will
# This is the story
# My left foot seems
# I have lost my
# My left foot is
# My left foot
#
# I trust my left
# I sat lame
# With left foot crossed
# If you hurt my
# My mind left
#
# `I have an
# Another day,
# My left foot is
# My left foot won
# I look boring
# Always, left
# My Left foot is
# The left foot
# re
# In a plane – "
# A left foot, it
# I can't feel
# Just one foot divides
# I walk with one foot
# my left foot hurt
#
# my left foot knows
#
# My left foot aches
# Ever under wise men
# Am I really the mon
# My left foot shuts
# An appleseed spr
# My left foot is ag
# I paint with my left
# My left foot writes po
# a painting is daub
# Long ago, when I
# My left foot paints
# My left foot flops
# Ticklish my left
# My left foot let me
# At the instructor'
# When I play piano
#
# astounding things:
#
# Feet carry me
#
# I step left
# with
# My left foot itches
# My left foot kicks
# My left foot falls
#
# Look, my left
#
# My left foot asks:
# My left foot
# has
# Fawning, so
# My left foot is
#
# My left foot
# str
# Green grass is warm
#
# I glide through sk
# While I was blind
# Quite legless,
# It is a dear foot
# My left foot paces
# My left foot:
#
# Today, like
# My left foot:
#
# A left foot is
#
# My left foot stays
#
# My left foot
# is
# This is the left side
# My left foot, it
# Haibun, Journal
# My left foot circles
#
# my left foot, my
# Left now, and my
# My left foot
# is
# My left foot hurts
# You are looking at
#
# I can’t put
# I press my left foot
# Breaking news:
#
# It's my left
# My left foot is
#
# Doing my push-
# My left foot lost –
# left and right; he
# this lost shoe
#
# This hip cracked
#
# My left foot, changed
# I’ll go this
# My left hand is
#
# Jumping to the
# I'm walking through
# Falling, again,
# asleep in a curl
# The Train Chugged
# Lack gumption.
# My left foot’s
# And now my left foot
# my left foot
# sett
# I wake twice ton
# my left foot,
#
# I rise each morning
#
# My left foot is heavy
# My left foot dangles
# 3D map, my
# I step into ice,
# my left foot is old
# My left foot doesn'
# They look into his brain
# My left foot is as
# Every morning I call
#
# My left foot is blue
# My left foot is
#
# Tapping my foot,
# while my left foot
#
# I break the ice
#
# If I lose control
#
# To my adoring
#
# My left foot,
#
# I am a starling
# It’s really my
# My left foot, cra
# The left foot will lead
# This is the story of
# My left foot seems
#
# I have lost my soul
# My left foot is a
# My left foot
# fe
# I trust my left foot
# I sat lame
#
# With left foot crossed
#
# If you hurt my left
# My mind left
# a
# `I have an old
# Another day, but
# My left foot is tired
# My left foot won'
# I look boringly
# Always, left sh
# My Left foot is big
# The left foot
# recent
# In a plane – "I
# A left foot, it hit
# I can't feel my
# Just one foot divides
#
# I walk with one foot left
# my left foot hurt
# in
# my left foot knows
# where
# My left foot aches;
# Ever under wise men'
# Am I really the monster
# My left foot shuts the
# An appleseed sprout
# My left foot is agile
# I paint with my left foot
# My left foot writes poems
# a painting is daubed
# Long ago, when I was
# My left foot paints a
# My left foot flops
#
# Ticklish my left foot
# My left foot let me down
# At the instructor's
# When I play piano
# I
# astounding things:
# I
# Feet carry me
# Under
# I step left
# with my
# My left foot itches
#
# My left foot kicks
#
# My left foot falls
# to
# Look, my left
# foot
# My left foot asks:
#
# My left foot
# has written
# Fawning, sobb
# My left foot is
# good
# My left foot
# stradd
# Green grass is warm
# under
# I glide through skies
# While I was blind
#
# Quite legless, she
# It is a dear foot
#
# My left foot paces the
# My left foot:
# A
# Today, like every
# My left foot:
# Sm
# A left foot is
# a
# My left foot stays
# tw
# My left foot
# is like
# This is the left side of
# My left foot, it has
# Haibun, Journal
# My left foot circles
# left
# my left foot, my left
# Left now, and my left
# My left foot
# is making
# My left foot hurts
#
# You are looking at
# my
# I can’t put any
# I press my left foot
#
# Breaking news:
# my
# It's my left foot
# My left foot is
# the
# Doing my push-up
# My left foot lost –
#
# left and right; heal
# this lost shoe
# is
# This hip cracked
# under
# My left foot, changed to
# I’ll go this way
# My left hand is
# a
# Jumping to the left
# I'm walking through town
# Falling, again,
#
# asleep in a curl
#
# The Train Chugged on
# Lack gumption.
#
# My left foot’s a
# And now my left foot
#
# my left foot
# settles
# I wake twice tonight
# my left foot,
# this
# I rise each morning
# limp
# My left foot is heavy
#
# My left foot dangles
#
# 3D map, my left
# I step into ice, crack
# my left foot is old and
# My left foot doesn't
# They look into his brain
#
# My left foot is asleep
# Every morning I call
# my
# My left foot is blue
#
# My left foot is
# my
# Tapping my foot,
#
# while my left foot
# is
# I break the ice
# With
# If I lose control
# of
# To my adoring
# gent
# My left foot,
# light
# I am a starling
#
# It’s really my right
# My left foot, crazy
# The left foot will lead
#
# This is the story of
#
# My left foot seems
# al
# I have lost my soul
#
# My left foot is a paper
# My left foot
# feels
# I trust my left foot
#
# I sat lame
# on
# With left foot crossed
# Over
# If you hurt my left foot
# My mind left
# a cig
# `I have an old
#
# Another day, but
#
# My left foot is tired on
# My left foot won't
# I look boringly down
# Always, left shoe
# My Left foot is big,
# The left foot
# recently
# In a plane – "I'
# A left foot, it hit,
# I can't feel my left
# Just one foot divides
# what
# I walk with one foot left.
# my left foot hurt
# in the
# my left foot knows
# where to
# My left foot aches;
#
# Ever under wise men's
# Am I really the monster
#
# My left foot shuts the door
# An appleseed sprout,
# My left foot is agile
#
# I paint with my left foot
#
# My left foot writes poems.
# a painting is daubed
#
# Long ago, when I was young
# My left foot paints a circle
# My left foot flops
# before
# Ticklish my left foot;
# My left foot let me down
#
# At the instructor's
#
# When I play piano
# I put
# astounding things:
# I type
# Feet carry me
# Under a
# I step left
# with my left
# My left foot itches
# But
# My left foot kicks
# t
# My left foot falls
# to the
# Look, my left
# foot is
# My left foot asks:
# How
# My left foot
# has written so
# Fawning, sobbing
# My left foot is
# good at
# My left foot
# straddles
# Green grass is warm
# under my
# I glide through skies
#
# While I was blind
# I
# Quite legless, she bent
# It is a dear foot
# L
# My left foot paces the floor
# My left foot:
# A f
# Today, like every day
# My left foot:
# Small
# A left foot is
# a witness
# My left foot stays
# twisted
# My left foot
# is like this
# This is the left side of my
# My left foot, it has decided
# Haibun, Journal 1
# My left foot circles
# left foot
# my left foot, my left foot
# Left now, and my left
#
# My left foot
# is making a
# My left foot hurts
# today
# You are looking at
# my left
# I can’t put any weight
# I press my left foot
# –
# Breaking news:
# my c
# It's my left foot,
# My left foot is
# the first
# Doing my push-up ex
# My left foot lost –
# my
# left and right; heal and
# this lost shoe
# is rolled
# This hip cracked
# under its
# My left foot, changed to
#
# I’ll go this way
#
# My left hand is
# a mouse
# Jumping to the left,
# I'm walking through town
#
# Falling, again,
# I
# asleep in a curl
# my
# The Train Chugged on.
# Lack gumption.
# Ex
# My left foot’s a mystery
# And now my left foot
# t
# my left foot
# settles into
# I wake twice tonight,
# my left foot,
# this perfect
# I rise each morning
# limping
# My left foot is heavy
# My
# My left foot dangles
# from
# 3D map, my left foot
# I step into ice, crack!
# my left foot is old and s
# My left foot doesn't know
# They look into his brain
# and
# My left foot is asleep
#
# Every morning I call
# my left
# My left foot is blue
# My
# My left foot is
# my best
# Tapping my foot,
# cling
# while my left foot
# is firm
# I break the ice
# With my
# If I lose control
# of my
# To my adoring
# gentle
# My left foot,
# light as
# I am a starling
# My
# It’s really my right foot
# My left foot, crazy,
# The left foot will lead
# The
# This is the story of
# my
# My left foot seems
# almost
# I have lost my soul
# all
# My left foot is a paper
#
# My left foot
# feels the
# I trust my left foot
# because
# I sat lame
# on the
# With left foot crossed
# Over right
# If you hurt my left foot
#
# My mind left
# a cigar
# `I have an old
# home
# Another day, but
# today
# My left foot is tired on the
# My left foot won't move
# I look boringly down,
# Always, left shoe
#
# My Left foot is big,
#
# The left foot
# recently happened
# In a plane – "I'm
# A left foot, it hit,
#
# I can't feel my left
#
# Just one foot divides
# what I
# I walk with one foot left.
#
# my left foot hurt
# in the morning
# my left foot knows
# where to go
# My left foot aches;
# I
# Ever under wise men's eyes
# Am I really the monster
# A
# My left foot shuts the door
#
# An appleseed sprout,
#
# My left foot is agile
# t
# I paint with my left foot
# (
# My left foot writes poems.
#
# a painting is daubed
# in
# Long ago, when I was young:
# My left foot paints a circle
#
# My left foot flops
# before my
# Ticklish my left foot;
#
# My left foot let me down
# when
# At the instructor's
# s
# When I play piano
# I put my
# astounding things:
# I type with
# Feet carry me
# Under a moon
# I step left
# with my left foot
# My left foot itches
# But I
# My left foot kicks
# tight
# My left foot falls
# to the side
# Look, my left
# foot is lay
# My left foot asks:
# How slow
# My left foot
# has written so much
# Fawning, sobbing eyes
# My left foot is
# good at only
# My left foot
# straddles a
# Green grass is warm
# under my tired
# I glide through skies
# with
# While I was blind
# I found
# Quite legless, she bent
#
# It is a dear foot
# Little
# My left foot paces the floor
#
# My left foot:
# A fidget
# Today, like every day
#
# My left foot:
# Small,
# A left foot is
# a witness to
# My left foot stays
# twisted,
# My left foot
# is like this left
# This is the left side of my face
# My left foot, it has decided.
# Haibun, Journal 1
#
# My left foot circles
# left foot circles
# my left foot, my left foot,
# Left now, and my left
# foot
# My left foot
# is making a st
# My left foot hurts
# today.
# You are looking at
# my left foot
# I can’t put any weight
#
# I press my left foot
# – burning
# Breaking news:
# my cyst
# It's my left foot,
#
# My left foot is
# the first thing
# Doing my push-up ex-
# My left foot lost –
# my teeth
# left and right; heal and toe
# this lost shoe
# is rolled in
# This hip cracked
# under its own
# My left foot, changed to
# stone
# I’ll go this way
# or
# My left hand is
# a mouse,
# Jumping to the left,
#
# I'm walking through town
# with
# Falling, again,
# I reach
# asleep in a curl
# my left
# The Train Chugged on.
#
# Lack gumption.
# Exud
# My left foot’s a mystery.
# And now my left foot
# tries
# my left foot
# settles into the
# I wake twice tonight,
#
# my left foot,
# this perfect,
# I rise each morning
# limping on
# My left foot is heavy
# My right
# My left foot dangles
# from my
# 3D map, my left foot:
# I step into ice, crack!
#
# my left foot is old and sore
# My left foot doesn't know
#
# They look into his brain
# and feel
# My left foot is asleep
# When
# Every morning I call
# my left foot
# My left foot is blue
# My husband
# My left foot is
# my best friend
# Tapping my foot,
# clinging
# while my left foot
# is firmly
# I break the ice
# With my left
# If I lose control
# of my left
# To my adoring
# gentle child
# My left foot,
# light as a
# I am a starling
# My left
# It’s really my right foot –
# My left foot, crazy,
#
# The left foot will lead
# The hand
# This is the story of
# my left
# My left foot seems
# almost perman
# I have lost my soul
# all the
# My left foot is a paper
# plane
# My left foot
# feels the cool
# I trust my left foot
# because it
# I sat lame
# on the sh
# With left foot crossed
# Over right where
# If you hurt my left foot
# I
# My mind left
# a cigar-
# `I have an old
# home in
# Another day, but
# today this
# My left foot is tired on the ground
# My left foot won't move
#
# I look boringly down,
#
# Always, left shoe
# On
# My Left foot is big,
# f
# The left foot
# recently happened –
# In a plane – "I'm okay
# A left foot, it hit,
# A
# I can't feel my left
# foot
# Just one foot divides
# what I write
# I walk with one foot left.
# Th
# my left foot hurt
# in the morning,
# my left foot knows
# where to go.
# My left foot aches;
# I cannot
# Ever under wise men's eyes.
# Am I really the monster
# A tw
# My left foot shuts the door
# on
# An appleseed sprout,
# my
# My left foot is agile
# till
# I paint with my left foot
# (my
# My left foot writes poems.
# My
# a painting is daubed
# in a
# Long ago, when I was young:
#
# My left foot paints a circle
# in
# My left foot flops
# before my right
# Ticklish my left foot;
# a
# My left foot let me down
# when I
# At the instructor's
# sugg
# When I play piano
# I put my left
# astounding things:
# I type with my
# Feet carry me
# Under a moon I
# I step left
# with my left foot
#
# My left foot itches
# But I cannot
# My left foot kicks
# tight against
# My left foot falls
# to the side,
# Look, my left
# foot is laying
# My left foot asks:
# How slow and
# My left foot
# has written so much
#
# Fawning, sobbing eyes,
# My left foot is
# good at only small
# My left foot
# straddles a pair
# Green grass is warm
# under my tired feet
# I glide through skies
# with only
# While I was blind
# I found my
# Quite legless, she bent
# over
# It is a dear foot
# Little by
# My left foot paces the floor
# while
# My left foot:
# A fidgeting
# Today, like every day
# at
# My left foot:
# Small,ging
# A left foot is
# a witness to grace
# My left foot stays
# twisted, on
# My left foot
# is like this left hand
# This is the left side of my face.
# My left foot, it has decided.
#
# Haibun, Journal 1
# My
# My left foot circles
# left foot circles right
# my left foot, my left foot, my
# Left now, and my left
# foot rest
# My left foot
# is making a stump
# My left foot hurts
# today. no
# You are looking at
# my left foot,
# I can’t put any weight
# on
# I press my left foot
# – burning –
# Breaking news:
# my cyst is
# It's my left foot,
# scr
# My left foot is
# the first thing I
# Doing my push-up ex-
#
# My left foot lost –
# my teeth,
# left and right; heal and toe;
# this lost shoe
# is rolled in the
# This hip cracked
# under its own weight
# My left foot, changed to
# stone by
# I’ll go this way
# or perhaps
# My left hand is
# a mouse, while
# Jumping to the left,
# (
# I'm walking through town
# with my
# Falling, again,
# I reach into
# asleep in a curl
# my left foot
# The Train Chugged on.
# Just
# Lack gumption.
# Exuding
# My left foot’s a mystery.
#
# And now my left foot
# tries to
# my left foot
# settles into the vast
# I wake twice tonight,
# left
# my left foot,
# this perfect, pain
# I rise each morning
# limping on my
# My left foot is heavy
# My right foot
# My left foot dangles
# from my chair
# 3D map, my left foot:
#
# I step into ice, crack!
# My
# my left foot is old and sore
#
# My left foot doesn't know
# what
# They look into his brain
# and feel pain
# My left foot is asleep
# When I
# Every morning I call
# my left foot my
# My left foot is blue
# My husband'
# My left foot is
# my best friend,
# Tapping my foot,
# clinging to
# while my left foot
# is firmly plant
# I break the ice
# With my left foot
# If I lose control
# of my left foot
# To my adoring
# gentle child,
# My left foot,
# light as a fe
# I am a starling
# My left foot
# It’s really my right foot –
#
# My left foot, crazy,
# h
# The left foot will lead
# The hand will
# This is the story of
# my left foot
# My left foot seems
# almost permanen
# I have lost my soul
# all the rain
# My left foot is a paper
# plane –
# My left foot
# feels the cool ground
# I trust my left foot
# because it is
# I sat lame
# on the shag
# With left foot crossed
# Over right where you
# If you hurt my left foot
# I go
# My mind left
# a cigar-sh
# `I have an old
# home in Pie
# Another day, but
# today this moment
# My left foot is tired on the ground
#
# My left foot won't move
# I
# I look boringly down,
# to
# Always, left shoe
# On,
# My Left foot is big,
# firm
# The left foot
# recently happened –
#
# In a plane – "I'm okay"
# A left foot, it hit,
# A right
# I can't feel my left
# foot;
# Just one foot divides
# what I write,
# I walk with one foot left.
# Though
# my left foot hurt
# in the morning, but
# my left foot knows
# where to go. I
# My left foot aches;
# I cannot walk
# Ever under wise men's eyes.
#
# Am I really the monster
# A twin
# My left foot shuts the door
# on the
# An appleseed sprout,
# my stub
# My left foot is agile
# till some
# I paint with my left foot
# (my left
# My left foot writes poems.
# My right
# a painting is daubed
# in a million
# Long ago, when I was young:
# This
# My left foot paints a circle
# in the
# My left foot flops
# before my right foot
# Ticklish my left foot;
# a born
# My left foot let me down
# when I needed
# At the instructor's
# suggestion
# When I play piano
# I put my left foot
# astounding things:
# I type with my left
# Feet carry me
# Under a moon I bare
# I step left
# with my left foot
# six
# My left foot itches
# But I cannot scratch
# My left foot kicks
# tight against the
# My left foot falls
# to the side, cast
# Look, my left
# foot is laying on
# My left foot asks:
# How slow and careful
# My left foot
# has written so much
# it
# Fawning, sobbing eyes,
#
# My left foot is
# good at only small
#
# My left foot
# straddles a pair of
# Green grass is warm
# under my tired feet as
# I glide through skies
# with only my
# While I was blind
# I found my left
# Quite legless, she bent
# over her
# It is a dear foot
# Little by little
# My left foot paces the floor
# while my
# My left foot:
# A fidgeting toe
# Today, like every day
# at this
# My left foot:
# Small,ginger
# A left foot is
# a witness to grace,
# My left foot stays
# twisted, on the
# My left foot
# is like this left hand,
# This is the left side of my face.
#
# My left foot, it has decided.
# I
# Haibun, Journal 1
# My left
# My left foot circles
# left foot circles right.
# my left foot, my left foot, my left
# Left now, and my left
# foot rests
# My left foot
# is making a stump.
# My left foot hurts
# today. no
#
# You are looking at
# my left foot, which
# I can’t put any weight
# on my
# I press my left foot
# – burning – on
# Breaking news:
# my cyst is gone
# It's my left foot,
# scratch
# My left foot is
# the first thing I see
# Doing my push-up ex-
# er
# My left foot lost –
# my teeth, my
# left and right; heal and toe;
#
# this lost shoe
# is rolled in the ocean
# This hip cracked
# under its own weight.
# My left foot, changed to
# stone by my
# I’ll go this way
# or perhaps that
# My left hand is
# a mouse, while my
# Jumping to the left,
# (under
# I'm walking through town
# with my left
# Falling, again,
# I reach into the
# asleep in a curl
# my left foot sm
# The Train Chugged on.
# Just my
# Lack gumption.
# Exuding res
# My left foot’s a mystery.
# You
# And now my left foot
# tries to follow
# my left foot
# settles into the vastness
# I wake twice tonight,
# left foot
# my left foot,
# this perfect, painful
# I rise each morning
# limping on my left
# My left foot is heavy
# My right foot is
# My left foot dangles
# from my chair when
# 3D map, my left foot:
# No
# I step into ice, crack!
# My left
# my left foot is old and sore
# my
# My left foot doesn't know
# what the
# They look into his brain
# and feel pain flash
# My left foot is asleep
# When I have
# Every morning I call
# my left foot my trou
# My left foot is blue
# My husband's
# My left foot is
# my best friend, my
# Tapping my foot,
# clinging to the
# while my left foot
# is firmly planted
# I break the ice
# With my left foot.
# If I lose control
# of my left foot,
# To my adoring
# gentle child, if
# My left foot,
# light as a feather
# I am a starling
# My left foot is
# It’s really my right foot –
# c
# My left foot, crazy,
# hur
# The left foot will lead
# The hand will reach
# This is the story of
# my left foot that
# My left foot seems
# almost permanen |
# I have lost my soul
# all the rain cle
# My left foot is a paper
# plane – win
# My left foot
# feels the cool ground
#
# I trust my left foot
# because it is my
# I sat lame
# on the shaggy
# With left foot crossed
# Over right where you lie
# If you hurt my left foot
# I go to
# My mind left
# a cigar-shaped
# `I have an old
# home in Pie Town
# Another day, but
# today this moment--
# My left foot is tired on the ground
# she
# My left foot won't move
# I pray
# I look boringly down,
# to watch
# Always, left shoe
# On, right
# My Left foot is big,
# firm,
# The left foot
# recently happened –
# al
# In a plane – "I'm okay"–
# A left foot, it hit,
# A right foot
# I can't feel my left
# foot; everyone
# Just one foot divides
# what I write, from
# I walk with one foot left.
# Though it
# my left foot hurt
# in the morning, but the
# my left foot knows
# where to go. I only
# My left foot aches;
# I cannot walk.
# Ever under wise men's eyes.
# My
# Am I really the monster
# A twin sister
# My left foot shuts the door
# on the house
# An appleseed sprout,
# my stub of
# My left foot is agile
# till some years
# I paint with my left foot
# (my left hand
# My left foot writes poems.
# My right foot
# a painting is daubed
# in a million places
# Long ago, when I was young:
# This left
# My left foot paints a circle
# in the sun
# My left foot flops
# before my right foot –
# Ticklish my left foot;
# a born child
# My left foot let me down
# when I needed to
# At the instructor's
# suggestion,
# When I play piano
# I put my left foot down
# astounding things:
# I type with my left foot
# Feet carry me
# Under a moon I barely
# I step left
# with my left foot
# six inches
# My left foot itches
# But I cannot scratch it
# My left foot kicks
# tight against the bed
# My left foot falls
# to the side, cast aside
# Look, my left
# foot is laying on its
# My left foot asks:
# How slow and careful?
# My left foot
# has written so much
# it finally
# Fawning, sobbing eyes,
# and
# My left foot is
# good at only small
# th
# My left foot
# straddles a pair of sho
# Green grass is warm
# under my tired feet as I
# I glide through skies
# with only my left
# While I was blind
# I found my left foot
# Quite legless, she bent
# over her wheel
# It is a dear foot
# Little by little.
# My left foot paces the floor
# while my right
# My left foot:
# A fidgeting toe
#
# Today, like every day
# at this prayer
# My left foot:
# Small,ginger,
# A left foot is
# a witness to grace,
#
# My left foot stays
# twisted, on the ground
# My left foot
# is like this left hand,
#
# This is the left side of my face.
# This
# My left foot, it has decided.
# I should
# Haibun, Journal 1
# My left foot
# My left foot circles
# left foot circles right.
#
# my left foot, my left foot, my left foot
# Left now, and my left
# foot rests on
# My left foot
# is making a stump.
#
# My left foot hurts
# today. no
# help
# You are looking at
# my left foot, which knows
# I can’t put any weight
# on my left
# I press my left foot
# – burning – on the
# Breaking news:
# my cyst is gone,
# It's my left foot,
# scratching
# My left foot is
# the first thing I see
#
# Doing my push-up ex-
# ercis
# My left foot lost –
# my teeth, my tongue
# left and right; heal and toe;
# many
# this lost shoe
# is rolled in the ocean
#
# This hip cracked
# under its own weight.
#
# My left foot, changed to
# stone by my first
# I’ll go this way
# or perhaps that other
# My left hand is
# a mouse, while my right
# Jumping to the left,
# (understand
# I'm walking through town
# with my left foot
# Falling, again,
# I reach into the earth
# asleep in a curl
# my left foot smiles
# The Train Chugged on.
# Just my left
# Lack gumption.
# Exuding resignation
# My left foot’s a mystery.
# You’
# And now my left foot
# tries to follow the
# my left foot
# settles into the vastness.
# I wake twice tonight,
# left foot:
# my left foot,
# this perfect, painful
#
# I rise each morning
# limping on my left foot
# My left foot is heavy
# My right foot is light
# My left foot dangles
# from my chair when as
# 3D map, my left foot:
# No image
# I step into ice, crack!
# My left foot
# my left foot is old and sore
# my left
# My left foot doesn't know
# what the right
# They look into his brain
# and feel pain flash on
# My left foot is asleep
# When I have dream
# Every morning I call
# my left foot my troublem
# My left foot is blue
# My husband's right
# My left foot is
# my best friend, my guide
# Tapping my foot,
# clinging to the rail
# while my left foot
# is firmly planted on
# I break the ice
# With my left foot.
#
# If I lose control
# of my left foot, I
# To my adoring
# gentle child, if I
# My left foot,
# light as a feather,
# I am a starling
# My left foot is magic
# It’s really my right foot –
# cold
# My left foot, crazy,
# hurts
# The left foot will lead
# The hand will reach
#
# This is the story of
# my left foot that dream
# My left foot seems
# almost permanen | t
# I have lost my soul
# all the rain clears
# My left foot is a paper
# plane – win,
# My left foot
# feels the cool ground
# w
# I trust my left foot
# because it is my left
# I sat lame
# on the shaggy brown
# With left foot crossed
# Over right where you lie –
# If you hurt my left foot
# I go to your
# My mind left
# a cigar-shaped shadow
# `I have an old
# home in Pie Town,
# Another day, but
# today this moment--
#
# My left foot is tired on the ground
# she pain
# My left foot won't move
# I pray the
# I look boringly down,
# to watch my
# Always, left shoe
# On, right left
# My Left foot is big,
# firm, and
# The left foot
# recently happened –
# almost
# In a plane – "I'm okay"–
#
# A left foot, it hit,
# A right foot,
# I can't feel my left
# foot; everyone looks
# Just one foot divides
# what I write, from my
# I walk with one foot left.
# Though it drag
# my left foot hurt
# in the morning, but the v
# my left foot knows
# where to go. I only
#
# My left foot aches;
# I cannot walk. And
# Ever under wise men's eyes.
# My beautiful
# Am I really the monster
# A twin sister once
# My left foot shuts the door
# on the house,
# An appleseed sprout,
# my stub of br
# My left foot is agile
# till some years pass
# I paint with my left foot
# (my left hand par
# My left foot writes poems.
# My right foot notes
# a painting is daubed
# in a million places,
# Long ago, when I was young:
# This left foot
# My left foot paints a circle
# in the sun,
# My left foot flops
# before my right foot –
#
# Ticklish my left foot;
# a born child with
# My left foot let me down
# when I needed to walk
# At the instructor's
# suggestion, we
# When I play piano
# I put my left foot down
#
# astounding things:
# I type with my left foot,
# Feet carry me
# Under a moon I barely trust
# I step left
# with my left foot
# six inches away
# My left foot itches
# But I cannot scratch it
#
# My left foot kicks
# tight against the bed frame
# My left foot falls
# to the side, cast aside,
# Look, my left
# foot is laying on its back
# My left foot asks:
# How slow and careful?
#
# My left foot
# has written so much
# it finally fell
# Fawning, sobbing eyes,
# and love
# My left foot is
# good at only small
# things
# My left foot
# straddles a pair of shoes
# Green grass is warm
# under my tired feet as I walk
# I glide through skies
# with only my left foot
# While I was blind
# I found my left foot
#
# Quite legless, she bent
# over her wheelch
# It is a dear foot
# Little by little. almost
# My left foot paces the floor
# while my right foot
# My left foot:
# A fidgeting toe
# P
# Today, like every day
# at this prayer wheel
# My left foot:
# Small,ginger,gr
# A left foot is
# a witness to grace,
# inn
# My left foot stays
# twisted, on the ground.
# My left foot
# is like this left hand,
# thick
# This is the left side of my face.
# This is
# My left foot, it has decided.
# I should pick
# Haibun, Journal 1
# My left foot hur
# My left foot circles
# left foot circles right.
# This
# my left foot, my left foot, my left foot,
# Left now, and my left
# foot rests on the
# My left foot
# is making a stump.
# Is
# My left foot hurts
# today. no
# help for
# You are looking at
# my left foot, which knows
#
# I can’t put any weight
# on my left foot
# I press my left foot
# – burning – on the train
# Breaking news:
# my cyst is gone, and
# It's my left foot,
# scratching the
# My left foot is
# the first thing I see
# in
# Doing my push-up ex-
# ercises
# My left foot lost –
# my teeth, my tongue,
# left and right; heal and toe;
# many things
# this lost shoe
# is rolled in the ocean
# ac
# This hip cracked
# under its own weight.
# It
# My left foot, changed to
# stone by my first birth
# I’ll go this way
# or perhaps that other road
# My left hand is
# a mouse, while my right hand
# Jumping to the left,
# (understandable
# I'm walking through town
# with my left foot,
# Falling, again,
# I reach into the earth.
# asleep in a curl
# my left foot smiles.
# The Train Chugged on.
# Just my left foot
# Lack gumption.
# Exuding resignation,
# My left foot’s a mystery.
# You’d
# And now my left foot
# tries to follow the right
# my left foot
# settles into the vastness.
#
# I wake twice tonight,
# left foot: Ob
# my left foot,
# this perfect, painful
# unique
# I rise each morning
# limping on my left foot.
# My left foot is heavy
# My right foot is light.
# My left foot dangles
# from my chair when asleep
# 3D map, my left foot:
# No image in
# I step into ice, crack!
# My left foot st
# my left foot is old and sore
# my left arm
# My left foot doesn't know
# what the right is
# They look into his brain
# and feel pain flash on and
# My left foot is asleep
# When I have dreams
# Every morning I call
# my left foot my troublemaker
# My left foot is blue
# My husband's right sh
# My left foot is
# my best friend, my guide to
# Tapping my foot,
# clinging to the rail,
# while my left foot
# is firmly planted on the
# I break the ice
# With my left foot.
# P
# If I lose control
# of my left foot, I fall
# To my adoring
# gentle child, if I
#
# My left foot,
# light as a feather,
#
# I am a starling
# My left foot is magic
#
# It’s really my right foot –
# cold as
# My left foot, crazy,
# hurts,
# The left foot will lead
# The hand will reach
# For
# This is the story of
# my left foot that dreams
# My left foot seems
# almost permanen | t,
# I have lost my soul
# all the rain clears from
# My left foot is a paper
# plane – win, win
# My left foot
# feels the cool ground
# warm
# I trust my left foot
# because it is my left foot
# I sat lame
# on the shaggy brown
#
# With left foot crossed
# Over right where you lie –
#
# If you hurt my left foot
# I go to your right
# My mind left
# a cigar-shaped shadow
#
# `I have an old
# home in Pie Town,
#
# Another day, but
# today this moment--
# I
# My left foot is tired on the ground
# she paints
# My left foot won't move
# I pray the world
# I look boringly down,
# to watch my left
# Always, left shoe
# On, right left free
# My Left foot is big,
# firm, and strong
# The left foot
# recently happened –
# almost on
# In a plane – "I'm okay"–
# In
# A left foot, it hit,
# A right foot, it
# I can't feel my left
# foot; everyone looks at
# Just one foot divides
# what I write, from my soul
# I walk with one foot left.
# Though it drags
# my left foot hurt
# in the morning, but the vet
# my left foot knows
# where to go. I only
# im
# My left foot aches;
# I cannot walk. And ton
# Ever under wise men's eyes.
# My beautiful left
# Am I really the monster
# A twin sister once had
# My left foot shuts the door
# on the house,
#
# An appleseed sprout,
# my stub of brist
# My left foot is agile
# till some years pass;
# I paint with my left foot
# (my left hand paral
# My left foot writes poems.
# My right foot notes them
# a painting is daubed
# in a million places,
#
# Long ago, when I was young:
# This left foot I
# My left foot paints a circle
# in the sun, and
# My left foot flops
# before my right foot –
# my
# Ticklish my left foot;
# a born child with my
# My left foot let me down
# when I needed to walk,
# At the instructor's
# suggestion, we write
# When I play piano
# I put my left foot down
# to
# astounding things:
# I type with my left foot,
#
# Feet carry me
# Under a moon I barely trust
#
# I step left
# with my left foot
# six inches away,
# My left foot itches
# But I cannot scratch it
# And
# My left foot kicks
# tight against the bed frame.
# My left foot falls
# to the side, cast aside,
#
# Look, my left
# foot is laying on its back!
# My left foot asks:
# How slow and careful?
# What
# My left foot
# has written so much
# it finally fell as
# Fawning, sobbing eyes,
# and love,
# My left foot is
# good at only small
# things:
# My left foot
# straddles a pair of shoes,
# Green grass is warm
# under my tired feet as I walk
#
# I glide through skies
# with only my left foot:
# While I was blind
# I found my left foot
# To
# Quite legless, she bent
# over her wheelchair
# It is a dear foot
# Little by little. almost
#
# My left foot paces the floor
# while my right foot t
# My left foot:
# A fidgeting toe
# Pow
# Today, like every day
# at this prayer wheel
#
# My left foot:
# Small,ginger,gritt
# A left foot is
# a witness to grace,
# innoc
# My left foot stays
# twisted, on the ground.
#
# My left foot
# is like this left hand,
# thick,
# This is the left side of my face.
# This is the
# My left foot, it has decided.
# I should pickle
# Haibun, Journal 1
# My left foot hurts
# My left foot circles
# left foot circles right.
# This ground
# my left foot, my left foot, my left foot,
#
# Left now, and my left
# foot rests on the floor
# My left foot
# is making a stump.
# Is my
# My left foot hurts
# today. no
# help for me
# You are looking at
# my left foot, which knows
# when
# I can’t put any weight
# on my left foot.
# I press my left foot
# – burning – on the train'
# Breaking news:
# my cyst is gone, and
#
# It's my left foot,
# scratching the d
# My left foot is
# the first thing I see
# in the
# Doing my push-up ex-
# ercises,
# My left foot lost –
# my teeth, my tongue, my
# left and right; heal and toe;
# many things dance
# this lost shoe
# is rolled in the ocean
# across
# This hip cracked
# under its own weight.
# It grew
# My left foot, changed to
# stone by my first birth,
# I’ll go this way
# or perhaps that other road.
# My left hand is
# a mouse, while my right hand
#
# Jumping to the left,
# (understandable),
# I'm walking through town
# with my left foot,
#
# Falling, again,
# I reach into the earth.
#
# asleep in a curl
# my left foot smiles. |
# The Train Chugged on.
# Just my left foot touched
# Lack gumption.
# Exuding resignation, I
# My left foot’s a mystery.
# You’d never
# And now my left foot
# tries to follow the right one
# my left foot
# settles into the vastness.
# there
# I wake twice tonight,
# left foot: Observe
# my left foot,
# this perfect, painful
# unique bless
# I rise each morning
# limping on my left foot.
#
# My left foot is heavy
# My right foot is light.
#
# My left foot dangles
# from my chair when asleep
#
# 3D map, my left foot:
# No image in your
# I step into ice, crack!
# My left foot sticks
# my left foot is old and sore
# my left arm is
# My left foot doesn't know
# what the right is doing
# They look into his brain
# and feel pain flash on and off
# My left foot is asleep
# When I have dreams of
# Every morning I call
# my left foot my troublemaker
#
# My left foot is blue
# My husband's right shoe
# My left foot is
# my best friend, my guide to poetry
# Tapping my foot,
# clinging to the rail,
#
# while my left foot
# is firmly planted on the ground
# I break the ice
# With my left foot.
# Pants
# If I lose control
# of my left foot, I fall.
# To my adoring
# gentle child, if I
# w
# My left foot,
# light as a feather,
# y
# I am a starling
# My left foot is magic
# Hel
# It’s really my right foot –
# cold as the
# My left foot, crazy,
# hurts, though
# The left foot will lead
# The hand will reach
# For a
# This is the story of
# my left foot that dreams
#
# My left foot seems
# almost permanen | t, turning
# I have lost my soul
# all the rain clears from my
# My left foot is a paper
# plane – win, win,
# My left foot
# feels the cool ground
# warming
# I trust my left foot
# because it is my left foot.
# I sat lame
# on the shaggy brown
# car
# With left foot crossed
# Over right where you lie –
# such
# If you hurt my left foot
# I go to your right hand
# My mind left
# a cigar-shaped shadow
# it
# `I have an old
# home in Pie Town,
# New
# Another day, but
# today this moment--
# I cannot
# My left foot is tired on the ground
# she paints the
# My left foot won't move
# I pray the world stops
# I look boringly down,
# to watch my left foot
# Always, left shoe
# On, right left free.
# My Left foot is big,
# firm, and strong.
# The left foot
# recently happened –
# almost on schedule
# In a plane – "I'm okay"–
# In a
# A left foot, it hit,
# A right foot, it keeps
# I can't feel my left
# foot; everyone looks at me
# Just one foot divides
# what I write, from my soul.
# I walk with one foot left.
# Though it drags and
# my left foot hurt
# in the morning, but the vet
#
# my left foot knows
# where to go. I only
# imagine
# My left foot aches;
# I cannot walk. And tonight
# Ever under wise men's eyes.
# My beautiful left foot
# Am I really the monster
# A twin sister once had.
# My left foot shuts the door
# on the house,
# My
# An appleseed sprout,
# my stub of bristle
# My left foot is agile
# till some years pass;
#
# I paint with my left foot
# (my left hand paralyz
# My left foot writes poems.
# My right foot notes them down
# a painting is daubed
# in a million places,
# but
# Long ago, when I was young:
# This left foot I had
# My left foot paints a circle
# in the sun, and though
# My left foot flops
# before my right foot –
# my left
# Ticklish my left foot;
# a born child with my father
# My left foot let me down
# when I needed to walk, but
# At the instructor's
# suggestion, we write
#
# When I play piano
# I put my left foot down
# to steady
# astounding things:
# I type with my left foot,
# now
# Feet carry me
# Under a moon I barely trust
# To
# I step left
# with my left foot
# six inches away,
#
# My left foot itches
# But I cannot scratch it
# And make
# My left foot kicks
# tight against the bed frame.
#
# My left foot falls
# to the side, cast aside,
# my
# Look, my left
# foot is laying on its back!
#
# My left foot asks:
# How slow and careful?
# What will
# My left foot
# has written so much
# it finally fell asleep
# Fawning, sobbing eyes,
# and love, drink
# My left foot is
# good at only small
# things: going
# My left foot
# straddles a pair of shoes,
#
# Green grass is warm
# under my tired feet as I walk
# With
# I glide through skies
# with only my left foot:
#
# While I was blind
# I found my left foot
# To keep
# Quite legless, she bent
# over her wheelchair and
# It is a dear foot
# Little by little. almost
# There
# My left foot paces the floor
# while my right foot taps
# My left foot:
# A fidgeting toe
# Powers
# Today, like every day
# at this prayer wheel
# My
# My left foot:
# Small,ginger,gritty
# A left foot is
# a witness to grace,
# innocent
# My left foot stays
# twisted, on the ground.
# The
# My left foot
# is like this left hand,
# thick, and
# This is the left side of my face.
# This is the right
# My left foot, it has decided.
# I should pickle it
# Haibun, Journal 1
# My left foot hurts
#
# My left foot circles
# left foot circles right.
# This ground su
# my left foot, my left foot, my left foot,
# my
# Left now, and my left
# foot rests on the floor…
# My left foot
# is making a stump.
# Is my writing
# My left foot hurts
# today. no
# help for me.
# You are looking at
# my left foot, which knows
# when I
# I can’t put any weight
# on my left foot.
# I press my left foot
# – burning – on the train's
# Breaking news:
# my cyst is gone, and
# so
# It's my left foot,
# scratching the dirt
# My left foot is
# the first thing I see
# in the morning
# Doing my push-up ex-
# ercises, I
# My left foot lost –
# my teeth, my tongue, my hair
# left and right; heal and toe;
# many things dance on
# this lost shoe
# is rolled in the ocean
# across Massachusetts
# This hip cracked
# under its own weight.
# It grew another
# My left foot, changed to
# stone by my first birth,
#
# I’ll go this way
# or perhaps that other road.
#
# My left hand is
# a mouse, while my right hand
# type
# Jumping to the left,
# (understandable),
#
# I'm walking through town
# with my left foot,
# as
# Falling, again,
# I reach into the earth.
# My
# asleep in a curl
# my left foot smiles. | left
# The Train Chugged on.
# Just my left foot touched the
# Lack gumption.
# Exuding resignation, I
#
# My left foot’s a mystery.
# You’d never guess
# And now my left foot
# tries to follow the right one.
# my left foot
# settles into the vastness.
# there'
# I wake twice tonight,
# left foot: Observe!
# my left foot,
# this perfect, painful
# unique blessing
# I rise each morning
# limping on my left foot.
#
#
# My left foot is heavy
# My right foot is light.
# D
# My left foot dangles
# from my chair when asleep
# I
# 3D map, my left foot:
# No image in your brain
# I step into ice, crack!
# My left foot sticks.
# my left foot is old and sore
# my left arm is weak
# My left foot doesn't know
# what the right is doing.
# They look into his brain
# and feel pain flash on and off.
# My left foot is asleep
# When I have dreams of flight
# Every morning I call
# my left foot my troublemaker
# and
# My left foot is blue
# My husband's right shoe
#
# My left foot is
# my best friend, my guide to poetry.
# Tapping my foot,
# clinging to the rail,
# on
# while my left foot
# is firmly planted on the ground,
# I break the ice
# With my left foot.
# Pants in
# If I lose control
# of my left foot, I fall.
#
# To my adoring
# gentle child, if I
# wake
# My left foot,
# light as a feather,
# yet
# I am a starling
# My left foot is magic
# Helps
# It’s really my right foot –
# cold as the night
# My left foot, crazy,
# hurts, though not
# The left foot will lead
# The hand will reach
# For a hand
# This is the story of
# my left foot that dreams
# of
# My left foot seems
# almost permanen | t, turning page
# I have lost my soul
# all the rain clears from my
#
# My left foot is a paper
# plane – win, win, I
# My left foot
# feels the cool ground
# warming up
# I trust my left foot
# because it is my left foot. When
# I sat lame
# on the shaggy brown
# carpet
# With left foot crossed
# Over right where you lie –
# such fun
# If you hurt my left foot
# I go to your right hand
#
# My mind left
# a cigar-shaped shadow
# it t
# `I have an old
# home in Pie Town,
# New Mexico
# Another day, but
# today this moment--
# I cannot use
# My left foot is tired on the ground
# she paints the tree
# My left foot won't move
# I pray the world stops
#
# I look boringly down,
# to watch my left foot walk
# Always, left shoe
# On, right left free. Yet
# My Left foot is big,
# firm, and strong.
#
# The left foot
# recently happened –
# almost on schedule.
# In a plane – "I'm okay"–
# In a crash
# A left foot, it hit,
# A right foot, it keeps swing
# I can't feel my left
# foot; everyone looks at me,
# Just one foot divides
# what I write, from my soul.
#
# I walk with one foot left.
# Though it drags and j
# my left foot hurt
# in the morning, but the vet
# pres
# my left foot knows
# where to go. I only
# imagine where
# My left foot aches;
# I cannot walk. And tonight
#
# Ever under wise men's eyes.
# My beautiful left foot.
# Am I really the monster
# A twin sister once had.
#
# My left foot shuts the door
# on the house,
# My right
# An appleseed sprout,
# my stub of bristle grows
# My left foot is agile
# till some years pass;
# then
# I paint with my left foot
# (my left hand paralyzed
# My left foot writes poems.
# My right foot notes them down.
# a painting is daubed
# in a million places,
# but on
# Long ago, when I was young:
# This left foot I had was
# My left foot paints a circle
# in the sun, and though
#
# My left foot flops
# before my right foot –
# my left hand
# Ticklish my left foot;
# a born child with my father.
# My left foot let me down
# when I needed to walk, but
#
# At the instructor's
# suggestion, we write
# with
# When I play piano
# I put my left foot down
# to steady my
# astounding things:
# I type with my left foot,
# now I
# Feet carry me
# Under a moon I barely trust
# To my
# I step left
# with my left foot
# six inches away,
# so
# My left foot itches
# But I cannot scratch it
# And make it
# My left foot kicks
# tight against the bed frame.
# But
# My left foot falls
# to the side, cast aside,
# my right
# Look, my left
# foot is laying on its back!
# It
# My left foot asks:
# How slow and careful?
# What will his
# My left foot
# has written so much
# it finally fell asleep.
# Fawning, sobbing eyes,
# and love, drinking
# My left foot is
# good at only small
# things: going up
# My left foot
# straddles a pair of shoes,
# and
# Green grass is warm
# under my tired feet as I walk
# With my
# I glide through skies
# with only my left foot:
#
#
# While I was blind
# I found my left foot
# To keep me
# Quite legless, she bent
# over her wheelchair and f
# It is a dear foot
# Little by little. almost
# There –
# My left foot paces the floor
# while my right foot taps my
# My left foot:
# A fidgeting toe
# Powers down
# Today, like every day
# at this prayer wheel
# My left
# My left foot:
# Small,ginger,gritty –
# A left foot is
# a witness to grace,
# innocent witness
# My left foot stays
# twisted, on the ground.
# The rest
# My left foot
# is like this left hand,
# thick, and filled
# This is the left side of my face.
# This is the right side
# My left foot, it has decided.
# I should pickle it in
# Haibun, Journal 1
# My left foot hurts
# when
# My left foot circles
# left foot circles right.
# This ground suits
# my left foot, my left foot, my left foot,
# my breath
# Left now, and my left
# foot rests on the floor…
#
# My left foot
# is making a stump.
# Is my writing still
# My left foot hurts
# today. no
# help for me.
#
# You are looking at
# my left foot, which knows
# when I am
# I can’t put any weight
# on my left foot.
#
# I press my left foot
# – burning – on the train's
#
# Breaking news:
# my cyst is gone, and
# so is
# It's my left foot,
# scratching the dirt
#
# My left foot is
# the first thing I see
# in the morning.
# Doing my push-up ex-
# ercises, I was
# My left foot lost –
# my teeth, my tongue, my hair,
# left and right; heal and toe;
# many things dance on
#
# this lost shoe
# is rolled in the ocean
# across Massachusetts
#
# This hip cracked
# under its own weight.
# It grew another to
# My left foot, changed to
# stone by my first birth,
# mov
# I’ll go this way
# or perhaps that other road.
# Left
# My left hand is
# a mouse, while my right hand
# type like
# Jumping to the left,
# (understandable),
# but
# I'm walking through town
# with my left foot,
# as if
# Falling, again,
# I reach into the earth.
# My left
# asleep in a curl
# my left foot smiles. | left foot
# The Train Chugged on.
# Just my left foot touched the ground
# Lack gumption.
# Exuding resignation, I
# grad
# My left foot’s a mystery.
# You’d never guess it
# And now my left foot
# tries to follow the right one.
#
# my left foot
# settles into the vastness.
# there's
# I wake twice tonight,
# left foot: Observe!
#
# my left foot,
# this perfect, painful
# unique blessing.
# I rise each morning
# limping on my left foot.
#
# 6
# My left foot is heavy
# My right foot is light.
# Dance
# My left foot dangles
# from my chair when asleep
# I still
# 3D map, my left foot:
# No image in your brain –
# I step into ice, crack!
# My left foot sticks. Nothing
# my left foot is old and sore
# my left arm is weak
#
# My left foot doesn't know
# what the right is doing.
#
# They look into his brain
# and feel pain flash on and off.
#
# My left foot is asleep
# When I have dreams of flight.
# ...
# I shall weep
# My left foot,
# light as a feather,
# yet the weight I carry.
#
# 8. "Wait
# I am a starling
# My left foot is magic
# Helps me fly far away.
#
# 6. "P
# It’s really my right foot –
# cold as the night grass –
# that steers me on, alone.
# My left foot, crazy,
# hurts, though not sure why.
# No appetite for dinner.
# The left foot will lead
# The hand will reach
# For a handkerchief –
# Breathless, I stand
# This is the story of
# my left foot that dreams
# of walking in two feet.
#
# 6. "Par
# My left foot seems
# almost permanen | t, turning page pages page.
# While right foot moves  |
# I have lost my soul
# all the rain clears from my
# left foot, heavy and sure
#
# Answer: Edit
# My left foot is a paper
# plane – win, win, I'm first.
#
# 6. "No Sug
# My left foot
# feels the cool ground
# warming up at sunrise.
#
# 6. "Oh
# I trust my left foot
# because it is my left foot. When
# I stumble, it catches me. Pre
# I sat lame
# on the shaggy brown
# carpet by the fire.
#
# 6. "Pho
# With left foot crossed
# Over right where you lie –
# such funny good looks!
#
#
# 6. "Box
# If you hurt my left foot
# I go to your right hand
# And laugh in your face!
#
# 6. "
# Another day, but
# today this moment--
# I cannot use my left foot.
# - Perhaps today you will
#
# My left foot is tired on the ground
# she paints the tree
# the tree and I and my left foot
# now
# My left foot won't move
# I pray the world stops
# 13¾ times a day.
#
# 6.
# I look boringly down,
# to watch my left foot walk
# at each step past me
# as if it knew
# Always, left shoe
# On, right left free. Yet this morning
# My right shoe
# Three drops
# My Left foot is big,
# firm, and strong.
#
# It does not give,
# but moves me forward
# A left foot, it hit,
# A right foot, it keeps swinging
# Left and right feet
# Make me a
# --------
# Poem 0 (weight 0.0):
# I can't feel my left
# foot; everyone looks at me,
# then I look at my foot.
#
#
# ------------------
#
# Poem 1 (weight 0.0):
# Just one foot divides
# what I write, from my soul.
# It is a painful threshold.
#
# 6
# ------------------
#
# Poem 2 (weight 0.0):
# I walk with one foot left.
# Though it drags and jerks –
# I can't stop,
# ------------------
#
# Poem 3 (weight 0.0):
# my left foot hurt
# in the morning, but the vet
# prescribed fancy leather.
#
# 5. "
# ------------------
#
# Poem 4 (weight 0.0):
# my left foot knows
# where to go. I only
# imagine where this path
#
# 5. "Moments
# ------------------
#
# Poem 5 (weight 0.0):
# My left foot aches;
# I cannot walk. And tonight
# maybe dinner will be stew.
#
# 6
# ------------------
#
# Poem 6 (weight 0.0):
# Ever under wise men's eyes.
# My beautiful left foot.
#
# 6. "Silk Hiding"
# ------------------
#
# Poem 7 (weight 0.0):
# Am I really the monster
# A twin sister once had.
#
# 6. "New Year's Eve
# ------------------
#
# Poem 8 (weight 0.0):
# My left foot shuts the door
# on the house,
# My right foot enters the house,
# and steps to my
# ------------------
#
# Poem 9 (weight 0.0):
# An appleseed sprout,
# my stub of bristle grows
# to a foot of springtime.
#
#
# ------------------
#
# Poem 10 (weight 0.0):
# My left foot is agile
# till some years pass;
# then it becomes my right foot,
# without a pause
# ------------------
#
# Poem 11 (weight 0.0):
# I paint with my left foot
# (my left hand paralyzed)
# and am so proud of my art.
# ------------------
#
# Poem 12 (weight 0.0):
# My left foot writes poems.
# My right foot notes them down.
# That’s why I need notebooks
# ------------------
#
# Poem 13 (weight 0.0):
# a painting is daubed
# in a million places,
# but on one vertical line
# a shadow takes true shape.
# ------------------
#
# Poem 14 (weight 0.0):
# Long ago, when I was young:
# This left foot I had was
# A thing of beauty,
# A glorious
# ------------------
#
# Poem 15 (weight 0.0):
# My left foot paints a circle
# in the sun, and though
# I tend to re-write,
# a free
# ------------------
#
# Poem 16 (weight 0.0):
# My left foot flops
# before my right foot –
# my left hand won’t work.
# To restore my world
# ------------------
#
# Poem 17 (weight 0.0):
# Ticklish my left foot;
# a born child with my father.
# This will be the life!
#
# 6
# ------------------
#
# Poem 18 (weight 0.0):
# My left foot let me down
# when I needed to walk, but
# it kept my falling balanced.
#
# 6
# ------------------
#
# Poem 19 (weight 0.0):
# At the instructor's
# suggestion, we write
# with our left foot, my left
# foot.
#
# ------------------
#
# Poem 20 (weight 0.0):
# When I play piano
# I put my left foot down
# to steady my hand
# But then, I’m not left
# ------------------
#
# Poem 21 (weight 0.0):
# astounding things:
# I type with my left foot,
# now I write with my right.
#
# 6. "
# ------------------
#
# Poem 22 (weight 0.0):
# Feet carry me
# Under a moon I barely trust
# To my left – hanging off the edge
# Is a
# ------------------
#
# Poem 23 (weight 0.0):
# I step left
# with my left foot
# six inches away,
# so I can pick it up again.
# Now,
# ------------------
#
# Poem 24 (weight 0.0):
# My left foot itches
# But I cannot scratch it
# And make it go away.
#
# 6. "Preci
# ------------------
#
# Poem 25 (weight 0.0):
# My left foot kicks
# tight against the bed frame.
# But this morning I can walk.
#
# 6.
# ------------------
#
# Poem 26 (weight 0.0):
# My left foot falls
# to the side, cast aside,
# my right foot steps forward.
#
# 6. "S
# ------------------
#
# Poem 27 (weight 0.0):
# Look, my left
# foot is laying on its back!
# It thinks again, this time
# sideways.
#
# ------------------
#
# Poem 28 (weight 0.0):
# My left foot asks:
# How slow and careful?
# What will his answer be?
#
# 6. "Autumn
# ------------------
#
# Poem 29 (weight 0.0):
# My left foot
# has written so much
# it finally fell asleep.
#
# 6. "The Book of Leo"
# ------------------
#
# Poem 30 (weight 0.0):
# Fawning, sobbing eyes,
# and love, drinking wine
# from a sense of right need.
#
# ------------------
#
# Poem 31 (weight 0.0):
# My left foot is
# good at only small
# things: going upstairs.
#
# 6. "Woman
# ------------------
#
# Poem 32 (weight 0.0):
# My left foot
# straddles a pair of shoes,
# and counts the jewels.
#
# 5.
# ------------------
#
# Poem 33 (weight 0.0):
# Green grass is warm
# under my tired feet as I walk
# With my left foot.
#
# 6. "Life is
# ------------------
#
# Poem 34 (weight 0.0):
# I glide through skies
# with only my left foot:
#
# broken yellow scars
# breathless,
# ------------------
#
# Poem 35 (weight 0.0):
# While I was blind
# I found my left foot
# To keep me upright.
#
# 6. "Pe
# ------------------
#
# Poem 36 (weight 0.0):
# Quite legless, she bent
# over her wheelchair and fussed
# with her left foot.
#
#
# ------------------
#
# Poem 37 (weight 0.0):
# It is a dear foot
# Little by little. almost
# There – now it’s grown. `~
#
#
# ------------------
#
# Poem 38 (weight 0.0):
# My left foot paces the floor
# while my right foot taps my right shoe.
# Do you want to come
# ------------------
#
# Poem 39 (weight 0.0):
# The left foot
# recently happened –
# almost on schedule.
# </s>
# ------------------
#
# Poem 40 (weight 0.0):
# My left foot:
# A fidgeting toe
# Powers down the elevator,
# walks the dog,
# ------------------
#
# Poem 41 (weight 0.0):
# Today, like every day
# at this prayer wheel
# My left foot turns it.
#
# 6. "T
# ------------------
#
# Poem 42 (weight 0.0):
# My left foot:
# Small,ginger,gritty –
# But always instrumental.
#
# 6.
# ------------------
#
# Poem 43 (weight 0.0):
# A left foot is
# a witness to grace,
# innocent witness,
# and to all that will
# pass.
# ------------------
#
# Poem 44 (weight 0.0):
# My left foot stays
# twisted, on the ground.
# The rest of me is free.
#
# #### Example of
# ------------------
#
# Poem 45 (weight 0.0):
# My left foot
# is like this left hand,
# thick, and filled with blood.
#
# 6. "Fingers
# ------------------
#
# Poem 46 (weight 0.0):
# This is the left side of my face.
# This is the right side of my face.
# When the two sides meet
# ------------------
#
# Poem 47 (weight 0.0):
# My left foot, it has decided.
# I should pickle it in brine.
# Its taste in frozen
# ------------------
#
# Poem 48 (weight 0.0):
# Haibun, Journal 1
# My left foot hurts
# when I go somewhere
# on my bad side.
#
# ------------------
#
# Poem 49 (weight 0.0):
# My left foot circles
# left foot circles right.
# This ground suits me fine.
#
# 6. "Shadows
# ------------------
#
# Poem 50 (weight 0.0):
# my left foot, my left foot, my left foot,
# my breath is slowing —
# my left hand, my
# ------------------
#
# Poem 51 (weight 0.0):
# Left now, and my left
# foot rests on the floor…
# I’m only one half
# asleep.
# ------------------
#
# Poem 52 (weight 0.0):
# My left foot
# is making a stump.
# Is my writing still
# kryptonite to you?
#
#
# ------------------
#
# Poem 53 (weight 0.0):
# My left foot hurts
# today. no
# help for me.
#
# 6. "Trees"
# There is
# ------------------
#
# Poem 54 (weight 0.0):
# You are looking at
# my left foot, which knows
# when I am in pain.
#
# 6. "Drawing"
# ------------------
#
# Poem 55 (weight 0.0):
# I can’t put any weight
# on my left foot.
# My toe feels disconnected.
#
# Feeling
# ------------------
#
# Poem 56 (weight 0.0):
# I press my left foot
# – burning – on the train's
# hot metal floor.
#
# 6. "Sign
# ------------------
#
# Poem 57 (weight 0.0):
# Breaking news:
# my cyst is gone, and
# so is my annual heat.
#
# 6. "Up
# ------------------
#
# Poem 58 (weight 0.0):
# It's my left foot,
# scratching the dirt
# for my right foot, which
# just hates
# ------------------
#
# Poem 59 (weight 0.0):
# My left foot is
# the first thing I see
# in the morning. (This one is intentionally ambiguous and def
# ------------------
#
# Poem 60 (weight 0.0):
# Doing my push-up ex-
# ercises, I was balanced
# upon my left foot.
#
# ------------------
#
# Poem 61 (weight 0.0):
# My left foot lost –
# my teeth, my tongue, my hair,
# but my left foot stays</s>
# ------------------
#
# Poem 62 (weight 0.0):
# left and right; heal and toe;
# many things dance on
# one little left foot.
#
# 6. "
# ------------------
#
# Poem 63 (weight 0.0):
# this lost shoe
# is rolled in the ocean
# across Massachusetts
#
#   Note: We are presuming here that
# ------------------
#
# Poem 64 (weight 0.0):
# This hip cracked
# under its own weight.
# It grew another tooth.
#
# They are not easy to write
# ------------------
#
# Poem 65 (weight 0.0):
# My left foot, changed to
# stone by my first birth,
# moves in water.
#
# 6. "App
# ------------------
#
# Poem 66 (weight 0.0):
# I’ll go this way
# or perhaps that other road.
# Left foot sets the rhythm.
#
# See also
# ------------------
#
# Poem 67 (weight 0.0):
# My left hand is
# a mouse, while my right hand
# type like it was invented for me.
# </s>
# ------------------
#
# Poem 68 (weight 0.0):
# Jumping to the left,
# (understandable),
# but jumping to the right
# is a skill.
# ------------------
#
# Poem 69 (weight 0.0):
# I'm walking through town
# with my left foot,
# as if I owned all the world.
#
# 6.
# ------------------
#
# Poem 70 (weight 0.0):
# Falling, again,
# I reach into the earth.
# My left foot, wrapped
# around a heart that runs
#
# ------------------
#
# Poem 71 (weight 0.0):
# asleep in a curl
# my left foot smiles. | left foot smiles
#
# 6. "Lost"
# ------------------
#
# Poem 72 (weight 0.0):
# The Train Chugged on.
# Just my left foot touched the ground.
# The train rumbled on.
#
#
# ------------------
#
# Poem 73 (weight 0.0):
# Lack gumption.
# Exuding resignation, I
# gradually raise a hand.
#
# 6. "
# ------------------
#
# Poem 74 (weight 0.0):
# My left foot’s a mystery.
# You’d never guess it -
# but there is a letter
# and you
# ------------------
#
# Poem 75 (weight 0.0):
# And now my left foot
# tries to follow the right one.
# A struggle, but …
#
# 6. "
# ------------------
#
# Poem 76 (weight 0.0):
# my left foot
# settles into the vastness.
# there's love there.
#
# 6. "Blizz
# ------------------
#
# Poem 77 (weight 0.0):
# I wake twice tonight,
# left foot: Observe!
#
# 6. "Deeper Wisdom"
#
# ------------------
#
# Poem 78 (weight 0.0):
# my left foot,
# this perfect, painful
# unique blessing.</s>
# ------------------
#
# Poem 79 (weight 0.0):
# In a plane – "I'm okay"–
# In a crash, only my left foot.
# Between
# ------------------
#
# Poem 80 (weight 0.0):
# I rise each morning
# limping on my left foot.
#
# 6. "Bicycle Tires"
# My
# ------------------
#
# Poem 81 (weight 0.0):
# My left foot is heavy
# My right foot is light.
# Dance partners take two, please.
#
# 6.
# ------------------
#
# Poem 82 (weight 0.0):
# My left foot dangles
# from my chair when asleep
# I still fall backwards.
#
# *
#
# These
# ------------------
#
# Poem 83 (weight 0.0):
# 3D map, my left foot:
# No image in your brain –
# Print sharp, re-align.
#
#
# ------------------
#
# Poem 84 (weight 0.0):
# I step into ice, crack!
# My left foot sticks. Nothing
# Easy about this drill.
#
#
# ------------------
#
# Poem 85 (weight 0.0):
# my left foot is old and sore
# my left arm is weak
# it could happen to anyone
# if they’re
# ------------------
#
# Poem 86 (weight 0.0):
# My left foot doesn't know
# what the right is doing.
#
# 6. "New day"
# The new
# ------------------
#
# Poem 87 (weight 0.0):
# They look into his brain
# and feel pain flash on and off.
# With stiff foot, he is moving on.
# ------------------
#
# Poem 88 (weight 0.0):
# My left foot is asleep
# When I have dreams of flight.
# It shifts suddenly awake.
#
#
# ------------------
#
# Poem 89 (weight 0.0):
# Every morning I call
# my left foot my troublemaker
# and say good morning.
#
# Next, let's
# ------------------
#
# Poem 90 (weight 0.0):
# My left foot is blue
# My husband's right shoe
# Is the color of love.
#
# 6. "
# ------------------
#
# Poem 91 (weight 0.0):
# My left foot is
# my best friend, my guide to poetry.
# Its lines do the writing.
#
# 6
# ------------------
#
# Poem 92 (weight 0.0):
# Tapping my foot,
# clinging to the rail,
# on the crowded ferry.
#
# 6. "
# ------------------
#
# Poem 93 (weight 0.0):
# while my left foot
# is firmly planted on the ground,
# the ground trembles.</s>
# ------------------
#
# Poem 94 (weight 0.0):
# I break the ice
# With my left foot.
# Pants in snow!
#
# 6. "Thought"
#
# ------------------
#
# Poem 95 (weight 0.0):
# If I lose control
# of my left foot, I fall.
# If I lose control
# of my mind, then I
# ------------------
#
# Poem 96 (weight 0.0):
# To my adoring
# gentle child, if I
# wake and find you’re dead
# I shall weep
# ------------------
#
# Poem 97 (weight 0.0):
# My left foot,
# light as a feather,
# yet the weight I carry.
#
# 8. "Wait
# ------------------
#
# Poem 98 (weight 0.0):
# I am a starling
# My left foot is magic
# Helps me fly far away.
#
# 6. "P
# ------------------
#
# Poem 99 (weight 0.0):
# It’s really my right foot –
# cold as the night grass –
# that steers me on, alone.
# ------------------
#
# Poem 100 (weight 0.0):
# My left foot, crazy,
# hurts, though not sure why.
# No appetite for dinner.
# ------------------
#
# Poem 101 (weight 0.0):
# The left foot will lead
# The hand will reach
# For a handkerchief –
# Breathless, I stand
# ------------------
#
# Poem 102 (weight 0.0):
# This is the story of
# my left foot that dreams
# of walking in two feet.
#
# 6. "Par
# ------------------
#
# Poem 103 (weight 0.0):
# My left foot seems
# almost permanen | t, turning page pages page.
# While right foot moves  |
# ------------------
#
# Poem 104 (weight 0.0):
# I have lost my soul
# all the rain clears from my
# left foot, heavy and sure
#
# Answer: Edit
# ------------------
#
# Poem 105 (weight 0.0):
# My left foot is a paper
# plane – win, win, I'm first.
#
# 6. "No Sug
# ------------------
#
# Poem 106 (weight 0.0):
# My left foot
# feels the cool ground
# warming up at sunrise.
#
# 6. "Oh
# ------------------
#
# Poem 107 (weight 0.0):
# I trust my left foot
# because it is my left foot. When
# I stumble, it catches me. Pre
# ------------------
#
# Poem 108 (weight 0.0):
# I sat lame
# on the shaggy brown
# carpet by the fire.
#
# 6. "Pho
# ------------------
#
# Poem 109 (weight 0.0):
# With left foot crossed
# Over right where you lie –
# such funny good looks!
#
#
# 6. "Box
# ------------------
#
# Poem 110 (weight 0.0):
# If you hurt my left foot
# I go to your right hand
# And laugh in your face!
#
# 6. "
# ------------------
#
# Poem 111 (weight 0.0):
# My mind left
# a cigar-shaped shadow
# it taps with my left foot.
# </s>
# ------------------
#
# Poem 112 (weight 0.0):
# `I have an old
# home in Pie Town,
# New Mexico. They say.`
# </s>
# ------------------
#
# Poem 113 (weight 0.0):
# Another day, but
# today this moment--
# I cannot use my left foot.
# - Perhaps today you will
#
# ------------------
#
# Poem 114 (weight 0.0):
# My left foot is tired on the ground
# she paints the tree
# the tree and I and my left foot
# now
# ------------------
#
# Poem 115 (weight 0.0):
# My left foot won't move
# I pray the world stops
# 13¾ times a day.
#
# 6.
# ------------------
#
# Poem 116 (weight 0.0):
# I look boringly down,
# to watch my left foot walk
# at each step past me
# as if it knew
# ------------------
#
# Poem 117 (weight 0.0):
# Always, left shoe
# On, right left free. Yet this morning
# My right shoe
# Three drops
# ------------------
#
# Poem 118 (weight 0.0):
# My Left foot is big,
# firm, and strong.
#
# It does not give,
# but moves me forward
# ------------------
#
# Poem 119 (weight 0.0):
# A left foot, it hit,
# A right foot, it keeps swinging
# Left and right feet
# Make me a
# ------------------

# %% [markdown]
# Now let's write a LLaMPPL program for generating Haiku's by conditioning on the desired target number of syllables.
#
# First, let's set up some globals and some useful masks.

# %%
SYLLABLES_PER_LINE = [5, 7, 5] # [5, 3, 5] for a Lune
NEWLINE_TOKEN      = 13

import string

# Useful masks
STARTS_NEW_WORD_MASK = set(i for (i,v) in enumerate(LLM.vocab) 
                           if v[0]==' ' and len(v) > 1 
                           and v[1] not in string.whitespace 
                           and v[1] not in string.punctuation)

CONTINUES_CURRENT_WORD_MASK = set(i for (i,v) in enumerate(LLM.vocab) 
                                  if all(c in '\'’' or c.isalpha() 
                                         for c in v))

NEW_WORD_AFTER_NEWLINE_OR_HYPHEN = STARTS_NEW_WORD_MASK.union(CONTINUES_CURRENT_WORD_MASK)

PUNCTUATION_MASK = set(i for (i,v) in enumerate(LLM.vocab) if v in ',:;.!?"-')

END_POEM_PUNCT = set(i for (i, v) in enumerate(LLM.vocab) if v in '.!?')

# %% [markdown]
# Now, let's implement our haiku `Model`.
#
# In this code we will make critical use of the `LMContext.mask_dist(MASK)` function. This function returns a special kind of *Bernoulli* distribution: a distribution over `True` and `False` which returns true with probability given by:
#
# $$P(\mathrm{True}) = \sum_{t \in \{ V_{\mathrm{LLM}} \cap  M \} } P_{\mathrm{LLM}}(t).$$
#
# In other words, it returns a distribution over a biased coin whose weight is the marginal likelihood of the mask, summing over the vocabulary. We can use this distribution in both the `sample` and `observe` functions:
#
#  - `sample(LMContext.mask_dist(MASK))`: This will flip a coin deciding to use a word in the mask or not. If the decision is to use the mask, then the `next_token` distribution of the `LMContext` will be updated to sample just from this mask (it will be conditioned on the mask).
#  - `observe(LMContext.mask_dist(MASK), True/False)`: Observing a mask to be `True` or `False` will force the `next_token` distribution of the `LMContext` to be conditioned on the mask or its complement (respectively) on the next call to `sample`.
#
# Both functions update the importance weights as expected.
#
# We will use Bernoulli mask distributions to break up the problem of sampling a word into steps where we first choose a *subset* of words and only later decide which word to use. This is a common pattern in LLaMPPL.

# %%
class Haiku(Model):
    
    def __init__(self, prompt):
        super().__init__()
        self.context = LMContext(LLM, prompt, 0.7)
        self.line_id = 0
        self.syllables_remaining = SYLLABLES_PER_LINE[self.line_id]
    
    async def step(self):
        
        line_id = self.line_id
        
        # Should the next word begin with a space?
        # (False at the start of a line, or after e.g. a hyphen)
        needs_space = False
        
        # Loop until this line is over
        while self.line_id == line_id:
            
            if needs_space:
                await self.observe(self.context.mask_dist(STARTS_NEW_WORD_MASK), True)
            else:
                await self.observe(self.context.mask_dist(NEW_WORD_AFTER_NEWLINE_OR_HYPHEN), True)

            # Generate a word
            word = ""
            num_tokens_in_word = 0
            
            while True:
                token = await self.sample(self.context.next_token())
                num_tokens_in_word += 1
                word += LLM.vocab[token.token_id]
                
                # Maximum number of tokens in a word, to avoid pathological
                # non-words the LLM sometimes spits out
                if num_tokens_in_word > 4:
                    await self.observe(self.context.mask_dist(CONTINUES_CURRENT_WORD_MASK), 
                                       False)
                    break
                else:
                    # Ask if the LLM wants to continue this word, or is done
                    if not await self.sample(self.context.mask_dist(CONTINUES_CURRENT_WORD_MASK)):
                        break

            needs_space = True
                        
            # Count syllables
            num_syllables = count_syllables(word.strip())
            
            # Reject if under/overstepped in num of syllables
            if not (num_syllables > 0 and self.syllables_remaining >= num_syllables):
                self.condition(False)
                self.finish()
                return
            
            # Otherwise, update syllables remaining
            self.syllables_remaining -= num_syllables
            
            # Finish line if necessary
            if self.syllables_remaining == 0:
                self.line_id += 1
                
                # If this was the last line, finish
                if self.line_id >= len(SYLLABLES_PER_LINE):
                    await self.observe(self.context.mask_dist(END_POEM_PUNCT), True)
                    await self.sample(self.context.next_token())
                    await self.observe(self.context.next_token(), LLM.tokenizer.eos_token_id)
                    self.finish()
                    return
                
                # Otherwise, advance to next line
                else:
                    self.syllables_remaining = SYLLABLES_PER_LINE[self.line_id]
                    
                    # Give a chance to add punctuation
                    if await self.sample(self.context.mask_dist(PUNCTUATION_MASK)):
                        punct = await self.sample(self.context.next_token())
                    
                    # Emit a newline
                    await self.observe(self.context.next_token(), NEWLINE_TOKEN)
                    needs_space = False
            
            # Do we want any (mid-line) punctuation?
            elif await self.sample(self.context.mask_dist(PUNCTUATION_MASK)):
                punct = await self.sample(self.context.next_token())
                if str(punct) == '-':
                    needs_space = False
            
        print(str(self.context))

# %%
LLM.batch_size = 40
particles = await smc_steer(Haiku(haiku_prompt), 20, 6)
#particles = await smc_standard(Haiku(haiku_prompt), 120)
print("--------")
for (i,particle) in enumerate(particles):
    print(f"Poem {i} (weight {particle.weight}):")
    print(f"{particle.context}\n------------------\n")

# %% [markdown]
# Here are some fun haikus generated for different titles.
#
# # Large Language
# I live and die in<br>
# the large language of the heart<br>
# which is not spoken.
#
# # My Ego
# My ego, so small,<br>
# it can't even hold me up.<br>
# I'm too big for that.
#
# # Cognitive Science
# A computer sits<br>
# in my living room. It is<br>
# also in my head.
#
# # Steered
# Here is a poem<br>
# all steered in your direction,<br>
# reaching out to you.
#
# Here is a poem<br>
# all steered in your direction,<br>
# not written by hand.
#
# # Hypothesis Generation
# My mother was a<br>
# mathematician. I was<br>
# her hypothesis.
#
# Hypotheses are<br>
# a hypothesis. We need<br>
# new ones to prove them.
#
# # Sampling Algorithm
# I write a program<br>
# to generate poetry,<br>
# and it writes itself.
#
# I sample your thoughts<br>
# and put them back together<br>
# to make a poem.
#
# A poem is a<br>
# sample from the entire<br>
# vastness of the world.
